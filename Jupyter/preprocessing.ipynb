# %%
# import libraries
import pandas as pd;
import requests
from sklearn.preprocessing import StandardScaler

# %%
# read CSVs
financials_2018 = pd.read_csv('../data/2018_Financial_Data.csv');

# %%
# print all industries available
financials_2018.Sector.unique()
# Out:
# array(['Consumer Cyclical', 'Energy', 'Technology', 'Industrials',
#        'Financial Services', 'Basic Materials', 'Communication Services',
#        'Consumer Defensive', 'Healthcare', 'Real Estate', 'Utilities'],
#       dtype=object)

# %%
# clean up data
# we only want companies from the consumer packaged goods industry, "Consumer Cyclical".
# we can consider "Consumer Defensive" as well?
consumer_2018 = financials_2018.loc[financials_2018['Sector'] == "Consumer Cyclical"];

# %%
# add name for ticker column
consumer_2018.rename(columns={consumer_2018.columns[0]: "Ticker"}, inplace=True)
consumer_2018.set_index('Ticker', inplace=True)
# Out:
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
pd.set_option('display.max_columns', 110)
pd.set_option('display.max_rows', 10)

# %%
# Remove specific keywords.
# Not used anymore, was used to isolate attributes.

#financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-5:] != 'ratio']
#financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'ratios']
financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-6:] != 'margin']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'turnover']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'growth']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-18:] != 'growth (per share)']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-9:] != 'per share']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'pershare']

# %%
# Select specific attributes from the consumer dataset
consumer_2018_accounts = consumer_2018[['Revenue',
                               'Cost of Revenue',
                               'Gross Profit',
                               'R&D Expenses',
                               'SG&A Expense',
                               'Operating Expenses',
                               'Operating Income',
                               'Interest Expense',
                               'Earnings before Tax',
                               'Income Tax Expense',
                               'Net Income',
                               'Preferred Dividends',
                               'Net Income Com',
                               'EBITDA',
                               'EBIT',
                               'Consolidated Income',
                               'Cash and cash equivalents',
                               'Short-term investments',
                               'Cash and short-term investments',
                               'Receivables',
                               'Inventories',
                               'Total current assets',
                               'Property, Plant & Equipment Net',
                               'Goodwill and Intangible Assets',
                               'Long-term investments',
                               'Tax assets',
                               'Total non-current assets',
                               'Total assets',
                               'Payables',
                               'Short-term debt',
                               'Total current liabilities',
                               'Long-term debt',
                               'Total debt',
                               'Deferred revenue',
                               'Tax Liabilities',
                               'Deposit Liabilities',
                               'Total non-current liabilities',
                               'Total liabilities',
                               'Other comprehensive income',
                               'Retained earnings (deficit)',
                               'Total shareholders equity',
                               'Investments',
                               'Net Debt',
                               'Other Assets',
                               'Other Liabilities',
                               'Depreciation & Amortization',
                               'Stock-based compensation',
                               'Operating Cash Flow',
                               'Capital Expenditure',
                               'Acquisitions and disposals',
                               'Investment purchases and sales',
                               'Investing Cash flow',
                               'Issuance (repayment) of debt',
                               'Issuance (buybacks) of shares',
                               'Dividend payments',
                               'Financing Cash Flow',
                               'Free Cash Flow',
                               'Market Cap',
                               'Enterprise Value',
                               'Working Capital',
                               '2019 PRICE VAR [%]',
                               'Class']]
consumer_2018_ratios = consumer_2018[['Net cash flow / Change in cash',
                                      'Average Payables',
                                      'Average Receivables',
                                      'currentRatio',
                                      'SG&A to Revenue',
                                      'daysOfPayablesOutstanding',
                                      'daysOfInventoryOutstanding',
                                      'eBITperRevenue',
                                      'Intangibles to Total Assets',
                                      'Debt to Assets',
                                      'Debt to Equity',
                                      'Payout Ratio',
                                      'ROE',
                                      'R&D to Revenue',
                                      'PE ratio',
                                      'returnOnAssets',
                                      'Dividend Yield']]

# %%
# Shows the rows that contain at least one nan
consumer_2018_accounts_nan_rows = consumer_2018_accounts[consumer_2018_accounts.isna().any(axis=1)]
consumer_2018_ratios_nan_rows = consumer_2018_ratios[consumer_2018_ratios.isna().any(axis=1)]

# %%
consumer_2018_ratios_nan_rows
# Out:
#         Net cash flow / Change in cash  Average Payables  Average Receivables  \
# Ticker
# LEN                      -1.092414e+09       879867500.0         1.872540e+08
# KBH                      -1.457420e+08       235754000.0         2.685215e+08
# DISCK                    -6.323000e+09               NaN                  NaN
# FOX                       1.525000e+09       184000000.0         1.763000e+09
# IMAX                     -1.713500e+07        28146000.0         2.403905e+08
# ...                                ...               ...                  ...
# HOVNP                    -2.610000e+08               NaN                  NaN
# LSXMB                    -5.230000e+08               NaN                  NaN
# NWHM                     -8.142800e+07        31556500.0         2.188350e+07
# QRTEB                    -2.520000e+08               NaN                  NaN
# UONEK                    -2.192100e+07         7500000.0         1.110000e+08
#
#         currentRatio  SG&A to Revenue  daysOfPayablesOutstanding  \
# Ticker
# LEN         5.149815           0.0167                    20.4892
# KBH         2.796366           0.0977                    20.7140
# DISCK            NaN              NaN                        NaN
# FOX         2.345000              NaN                        NaN
# IMAX        2.231638           0.3138                    31.2521
# ...              ...              ...                        ...
# HOVNP            NaN              NaN                        NaN
# LSXMB            NaN              NaN                        NaN
# NWHM        9.283635           0.0929                    21.5375
# QRTEB            NaN              NaN                        NaN
# UONEK       1.558559           0.3643                     5.8187
#
#         daysOfInventoryOutstanding  eBITperRevenue  \
# Ticker
# LEN                         4.2022        0.108937
# KBH                        23.5062        0.080925
# DISCK                          NaN             NaN
# FOX                            NaN             NaN
# IMAX                      215.1983        0.094225
# ...                            ...             ...
# HOVNP                          NaN             NaN
# LSXMB                          NaN             NaN
# NWHM                       10.6526       -0.030395
# QRTEB                          NaN             NaN
# UONEK                      91.4374        0.000000
#
#         Intangibles to Total Assets  Debt to Assets  Debt to Equity  \
# Ticker
# LEN                          0.1205          0.2991          0.5859
# KBH                          0.0000          0.4061          0.9870
# DISCK                           NaN             NaN             NaN
# FOX                          0.2094          1.4879          2.0349
# IMAX                         0.0837          0.0432          0.0737
# ...                             ...             ...             ...
# HOVNP                           NaN             NaN             NaN
# LSXMB                           NaN             NaN             NaN
# NWHM                         0.0000          0.5569          1.6155
# QRTEB                           NaN             NaN             NaN
# UONEK                           NaN             NaN             NaN
#
#         Payout Ratio     ROE  R&D to Revenue  PE ratio  returnOnAssets  \
# Ticker
# LEN            0.029  0.1163          0.0000    7.8260             NaN
# KBH            0.052  0.0816          0.0000   10.9378             NaN
# DISCK            NaN     NaN             NaN       NaN             NaN
# FOX            0.149     NaN             NaN       NaN             NaN
# IMAX           0.000  0.0446          0.0367   52.2500             NaN
# ...              ...     ...             ...       ...             ...
# HOVNP            NaN     NaN             NaN       NaN             NaN
# LSXMB            NaN     NaN             NaN       NaN             NaN
# NWHM           0.000 -0.0592          0.0000    0.0000             NaN
# QRTEB            NaN     NaN             NaN       NaN             NaN
# UONEK            NaN     NaN             NaN       NaN             NaN
#
#         Dividend Yield
# Ticker
# LEN             0.0037
# KBH             0.0047
# DISCK              NaN
# FOX                NaN
# IMAX            0.0000
# ...                ...
# HOVNP              NaN
# LSXMB              NaN
# NWHM            0.0000
# QRTEB              NaN
# UONEK              NaN
#
# [46 rows x 17 columns]

# %%
# Shows the number of nans in each column (accounts dataset)
consumer_2018_accounts.isnull().sum().sort_values()
# Out:
# Total current liabilities         0
# Financing Cash Flow               0
# Investing Cash flow               0
# Capital Expenditure               0
# Operating Cash Flow               0
#                                  ..
# Total non-current assets         32
# Total non-current liabilities    33
# Market Cap                       34
# Working Capital                  45
# Enterprise Value                 65
# Length: 62, dtype: int64

# %%
# Shows the number of nans in each column (ratios dataset)
consumer_2018_ratios.isnull().sum().sort_values()
# Out:
# Net cash flow / Change in cash     1
# Average Payables                  11
# Average Receivables               11
# currentRatio                      12
# SG&A to Revenue                   13
#                                   ..
# ROE                               19
# R&D to Revenue                    19
# PE ratio                          19
# Dividend Yield                    19
# returnOnAssets                    46
# Length: 17, dtype: int64

# %%
# Drops the nan rows from the dataset
consumer_2018_accounts = consumer_2018_accounts.dropna()
consumer_2018_ratios = consumer_2018_ratios.dropna()

# %%
# Normalize Values
scaler = StandardScaler().fit(consumer_2018_accounts)
consumer_2018_accounts_scaled = scaler.transform(consumer_2018_accounts)

scaler = StandardScaler().fit(consumer_2018_ratios)
consumer_2018_ratios_scaled = scaler.transform(consumer_2018_ratios)

# %%
# Reconstruct Dataframe after normalization
consumer_2018_accounts_scaled = pd.DataFrame(consumer_2018_accounts_scaled, columns=consumer_2018_accounts.columns, index=consumer_2018_accounts.index)
consumer_2018_ratios_scaled = pd.DataFrame(consumer_2018_ratios_scaled, columns=consumer_2018_ratios.columns, index=consumer_2018_ratios.index)

# %% [markdown]
# ### Yahoo Finance API
# ##### Used to convert ticker names to company names

# %%
def getCompanyName(ticker):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(ticker)

    result = requests.get(url).json()

    for x in result['ResultSet']['Result']:
        if x['symbol'] == ticker:
            return x['name']

# %% [markdown]
# ##### Calls the Yahoo API. Only run if necessary. Takes a minute or two to get all the data from Yahoo servers.

# %%
consumer_2018_accounts_final = consumer_2018_accounts_scaled
consumer_2018_accounts_final['Name'] = consumer_2018_accounts_final.apply(lambda row : getCompanyName(row.name), axis = 1)

# %%
consumer_2018_ratios_final = consumer_2018_ratios_scaled
consumer_2018_ratios_final['Name'] = consumer_2018_ratios_final.apply(lambda row : getCompanyName(row.name), axis = 1)

# %% [markdown]
# ##### Removes Tickers that are not found on Yahoo Finance

# %%
consumer_2018_accounts_final = consumer_2018_accounts_final[consumer_2018_accounts_final['Name'].isnull() == False]
consumer_2018_ratios_final = consumer_2018_ratios_final[consumer_2018_ratios_final['Name'].isnull() == False]

# %% [markdown]
# ### Consumer 2018 Dataset with only accounts

# %%
consumer_2018_accounts_final
# Out:
#           Revenue  Cost of Revenue  Gross Profit  R&D Expenses  SG&A Expense  \
# Ticker
# CMCSA    6.323475        -0.316696     16.416107     -0.158625     17.261727
# SIRI     0.030446        -0.108048      0.288030      0.791809      0.060087
# CZR      0.216274         0.061176      0.420518     -0.158625      0.271835
# F       10.992098        12.854323      2.262109     -0.158625      2.793410
# NKE      2.202412         1.530728      2.501254     -0.158625      2.822662
# ...           ...              ...           ...           ...           ...
# TKAT    -0.378199        -0.316463     -0.324211     -0.158625     -0.291735
# UONE    -0.347661        -0.305365     -0.269683     -0.158625     -0.244763
# VNCE    -0.359470        -0.303067     -0.303684     -0.158625     -0.257098
# WINA    -0.373659        -0.316273     -0.313241     -0.158625     -0.287993
# XELB    -0.376286        -0.316451     -0.319455     -0.158625     -0.288419
#
#         Operating Expenses  Operating Income  Interest Expense  \
# Ticker
# CMCSA            17.384583         11.478611         14.515810
# SIRI              0.099691          0.746462          1.084121
# CZR               0.506456          0.132946          5.275000
# F                 2.365166          1.663089          4.778454
# NKE               2.390474          2.434371         -0.161760
# ...                    ...               ...               ...
# TKAT             -0.303959         -0.330107         -0.386579
# UONE             -0.250644         -0.280242         -0.066377
# VNCE             -0.274074         -0.337347         -0.365681
# WINA             -0.300804         -0.300013         -0.378554
# XELB             -0.300149         -0.323532         -0.384739
#
#         Earnings before Tax  Income Tax Expense  Net Income  \
# Ticker
# CMCSA              9.775665            8.563799    9.567104
# SIRI               0.643699            0.377755    0.690954
# CZR               -0.182470           -0.577006   -0.043092
# F                  2.582381            1.436007    2.794220
# NKE                2.581047            5.984218    1.327631
# ...                     ...                 ...         ...
# TKAT              -0.309281           -0.262339   -0.304313
# UONE              -0.302374           -0.623371   -0.179323
# VNCE              -0.265166           -0.262579   -0.248619
# WINA              -0.277667           -0.237176   -0.272562
# XELB              -0.301923           -0.256305   -0.296980
#
#         Preferred Dividends  Net Income Com     EBITDA       EBIT  \
# Ticker
# CMCSA             -0.099857        9.579568  11.569099  10.840223
# SIRI              -0.099857        0.692673   0.515836   0.731833
# CZR               -0.099857       -0.042262   0.759805   0.586547
# F                 -0.099857        2.798485   5.297470   2.997732
# NKE               -0.099857        1.330120   1.754523   2.293597
# ...                     ...             ...        ...        ...
# TKAT              -0.099857       -0.303799  -0.326819  -0.332864
# UONE              -0.099857       -0.178657  -0.278668  -0.281103
# VNCE              -0.099857       -0.248037  -0.294254  -0.290291
# WINA              -0.099857       -0.272009  -0.307062  -0.303344
# XELB              -0.099857       -0.296457  -0.321810  -0.325997
#
#         Consolidated Income  Cash and cash equivalents  \
# Ticker
# CMCSA              9.520019                   2.244294
# SIRI               0.673011                  -0.260471
# CZR               -0.048827                   0.807385
# F                  2.758575                  10.840435
# NKE                1.299819                   2.534074
# ...                     ...                        ...
# TKAT              -0.306827                  -0.288101
# UONE              -0.182811                  -0.285859
# VNCE              -0.251996                  -0.292865
# WINA              -0.275568                  -0.294728
# XELB              -0.299608                  -0.290557
#
#         Short-term investments  Cash and short-term investments  Receivables  \
# Ticker
# CMCSA                -0.106862                         1.441824     1.531506
# SIRI                 -0.106862                        -0.216057    -0.099790
# CZR                  -0.106862                         0.490747    -0.065276
# F                    18.493903                        14.730005    18.036236
# NKE                   0.968190                         2.072789     0.390154
# ...                        ...                              ...          ...
# TKAT                 -0.104280                        -0.233290    -0.133782
# UONE                 -0.106862                        -0.232861    -0.118194
# VNCE                 -0.106862                        -0.237498    -0.131638
# WINA                 -0.086842                        -0.230553    -0.134521
# XELB                 -0.106862                        -0.235970    -0.133101
#
#         Inventories  Total current assets  Property, Plant & Equipment Net  \
# Ticker
# CMCSA     -0.400089              2.809216                         7.001565
# SIRI      -0.384364             -0.200446                        -0.038656
# CZR       -0.370784              0.051227                         2.344824
# F          7.619462             15.878923                         5.646958
# NKE        3.360237              1.863644                         0.443715
# ...             ...                   ...                              ...
# TKAT      -0.400089             -0.264618                        -0.286575
# UONE      -0.400089             -0.243373                        -0.282533
# VNCE      -0.365123             -0.256277                        -0.281628
# WINA      -0.400012             -0.264350                        -0.286670
# XELB      -0.398668             -0.264403                        -0.286287
#
#         Goodwill and Intangible Assets  Long-term investments  Tax assets  \
# Ticker
# CMCSA                        18.743526               4.289677   -0.102002
# SIRI                          0.348493              -0.127622    0.121291
# CZR                           0.600415              -0.127622   -0.094381
# F                            -0.192743              17.707441    7.832903
# NKE                          -0.143150              -0.127622    1.810087
# ...                                ...                    ...         ...
# TKAT                         -0.192741              -0.127622   -0.101536
# UONE                         -0.076722              -0.127622   -0.102002
# VNCE                         -0.179353              -0.127622   -0.101713
# WINA                         -0.192675              -0.116159   -0.101571
# XELB                         -0.180431              -0.126791   -0.102002
#
#         Total non-current assets  Total assets   Payables  Short-term debt  \
# Ticker
# CMCSA                  13.793384     11.116615   4.114927         1.311408
# SIRI                    0.206128      0.088385   0.073328        -0.116453
# CZR                     1.173452      0.885552  -0.102236        -0.057649
# F                       8.414227     11.336535  10.900938        17.261537
# NKE                     0.188206      0.738862   0.877167        -0.006318
# ...                          ...           ...        ...              ...
# TKAT                   -0.264401     -0.280645  -0.306772        -0.116616
# UONE                   -0.199445     -0.225717  -0.286873        -0.104853
# VNCE                   -0.255181     -0.271136  -0.298347        -0.114829
# WINA                   -0.263166     -0.279644  -0.309394        -0.116376
# XELB                   -0.257553     -0.275505  -0.307420        -0.114739
#
#         Total current liabilities  Long-term debt  Total debt  \
# Ticker
# CMCSA                    3.966232       12.201164    9.828164
# SIRI                     0.191259        0.529112    0.378288
# CZR                      0.069029        1.920208    1.473647
# F                       14.311788       11.431432   13.655699
# NKE                      0.683984        0.132104    0.100889
# ...                           ...             ...         ...
# TKAT                    -0.233258       -0.270829   -0.242255
# UONE                    -0.218466       -0.169311   -0.160247
# VNCE                    -0.228527       -0.266103   -0.238093
# WINA                    -0.233504       -0.267854   -0.239881
# XELB                    -0.232951       -0.269516   -0.240717
#
#         Deferred revenue  Tax Liabilities  Deposit Liabilities  \
# Ticker
# CMCSA           3.823651        19.382472            -0.094029
# SIRI            3.637748        -0.116090            -0.094029
# CZR            -0.192601         0.367445            -0.094029
# F              -0.192601         0.273287            -0.094029
# NKE            -0.192601         2.233621            -0.094029
# ...                  ...              ...                  ...
# TKAT           -0.192601        -0.149353            -0.077590
# UONE           -0.192601        -0.140228            -0.094029
# VNCE           -0.192601        -0.149364            -0.094029
# WINA           -0.173868        -0.148551            -0.094029
# XELB           -0.192601        -0.143602            -0.094029
#
#         Total non-current liabilities  Total liabilities  \
# Ticker
# CMCSA                       12.966876          10.086410
# SIRI                         0.362239           0.312255
# CZR                          1.518892           1.031313
# F                           10.638381          12.471832
# NKE                          0.318330           0.470197
# ...                               ...                ...
# TKAT                        -0.265147          -0.264049
# UONE                        -0.183024          -0.204088
# VNCE                        -0.255144          -0.255634
# WINA                        -0.261744          -0.261890
# XELB                        -0.263221          -0.262658
#
#         Other comprehensive income  Retained earnings (deficit)  \
# Ticker
# CMCSA                    -0.275867                     6.381373
# SIRI                      0.239820                    -0.549475
# CZR                       0.248367                    -1.858059
# F                       -10.244848                     3.341652
# NKE                       0.117309                     0.327740
# ...                            ...                          ...
# TKAT                      0.247936                    -0.225048
# UONE                      0.248367                    -0.352210
# VNCE                      0.248274                    -0.389207
# WINA                      0.248367                    -0.227206
# XELB                      0.248367                    -0.225789
#
#         Total shareholders equity  Investments   Net Debt  Other Assets  \
# Ticker
# CMCSA                   12.989011     2.836135  11.403689      2.487901
# SIRI                    -0.623809    -0.122260   0.505127      0.096857
# CZR                      0.315537    -0.122260   1.642579      0.073870
# F                        6.374289    18.289744  12.733250    -18.216320
# NKE                      1.532033     0.251527  -0.386314      0.436717
# ...                           ...          ...        ...           ...
# TKAT                    -0.285023    -0.121362  -0.232952      0.037428
# UONE                    -0.254496    -0.122260  -0.134958      0.053696
# VNCE                    -0.273103    -0.122260  -0.226944      0.039396
# WINA                    -0.287855    -0.107622  -0.230781      0.037609
# XELB                    -0.268447    -0.121704  -0.230456      0.037812
#
#         Other Liabilities  Depreciation & Amortization  \
# Ticker
# CMCSA            7.012560                    10.629151
# SIRI             0.732689                     0.051191
# CZR              0.411421                     0.911964
# F                9.914896                     8.214893
# NKE              1.405515                     0.506189
# ...                   ...                          ...
# TKAT            -0.289601                    -0.254491
# UONE            -0.278292                    -0.221567
# VNCE            -0.284930                    -0.245109
# WINA            -0.288270                    -0.255084
# XELB            -0.290849                    -0.253589
#
#         Stock-based compensation  Operating Cash Flow  Capital Expenditure  \
# Ticker
# CMCSA                  10.925109            11.607258           -12.993765
# SIRI                    1.444415             0.605673            -0.102241
# CZR                     0.703078             0.068556            -0.327910
# F                       2.235698             7.055284            -8.112661
# NKE                     2.605169             2.114613            -0.823891
# ...                          ...                  ...                  ...
# TKAT                   -0.375228            -0.328502             0.280660
# UONE                   -0.313501            -0.292545             0.276511
# VNCE                   -0.362394            -0.337010             0.277642
# WINA                   -0.345400            -0.300050             0.255625
# XELB                   -0.353500            -0.313960             0.279693
#
#         Acquisitions and disposals  Investment purchases and sales  \
# Ticker
# CMCSA                   -19.496825                       -2.196658
# SIRI                      0.093436                        0.016154
# CZR                      -0.710531                        0.066816
# F                         0.101655                      -14.668792
# NKE                       0.101655                        2.378110
# ...                            ...                             ...
# TKAT                      0.104282                        0.018341
# UONE                      0.105787                        0.029623
# VNCE                      0.101655                        0.029623
# WINA                      0.101655                        0.072576
# XELB                      0.101655                        0.029623
#
#         Investing Cash flow  Issuance (repayment) of debt  \
# Ticker
# CMCSA            -17.466172                     18.551872
# SIRI               0.035308                     -0.046505
# CZR               -0.573468                      0.204339
# F                 -5.471482                      1.502671
# NKE                0.262517                     -0.116395
# ...                     ...                           ...
# TKAT               0.166177                     -0.107708
# UONE               0.167927                     -0.135538
# VNCE               0.165645                     -0.108338
# WINA               0.166974                     -0.128018
# XELB               0.166305                     -0.110985
#
#         Issuance (buybacks) of shares  Dividend payments  Financing Cash Flow  \
# Ticker
# CMCSA                       -6.246506          -7.472656            15.388109
# SIRI                        -1.333279          -0.184554            -0.769809
# CZR                         -0.095345           0.281416             0.252015
# F                            0.077599          -6.438625             0.015751
# NKE                         -4.039938          -2.593975            -2.641791
# ...                               ...                ...                  ...
# TKAT                         0.278753           0.281416             0.085067
# UONE                         0.267529           0.281416             0.042056
# VNCE                         0.314290           0.281416             0.100423
# WINA                         0.279947           0.276397             0.065384
# XELB                         0.277486           0.281416             0.080883
#
#         Free Cash Flow  Market Cap  Enterprise Value  Working Capital  \
# Ticker
# CMCSA         9.286260    7.256458          9.706136        -4.157145
# SIRI          0.909300    0.919989          0.897186        -1.822499
# CZR          -0.134760   -0.098078          0.505200        -0.059603
# F             5.483897    1.167930          5.422933        12.746919
# NKE           2.835536    5.339784          4.032573         5.949899
# ...                ...         ...               ...              ...
# TKAT         -0.330657   -0.320130         -0.332647        -0.234363
# UONE         -0.275066   -0.315699         -0.294470        -0.197830
# VNCE         -0.346782   -0.316220         -0.327465        -0.215203
# WINA         -0.302824   -0.290164         -0.308479        -0.231966
# XELB         -0.307647   -0.319493         -0.331265        -0.234695
#
#         2019 PRICE VAR [%]     Class                         Name
# Ticker
# CMCSA             0.272457  0.766672          Comcast Corporation
# SIRI              0.101756  0.766672      Sirius XM Holdings Inc.
# CZR               1.295726  0.766672  Caesars Entertainment, Inc.
# F                 0.155944  0.766672           Ford Motor Company
# NKE               0.359933  0.766672                   NIKE, Inc.
# ...                    ...       ...                          ...
# TKAT             -0.732742 -1.304338         Takung Art Co., Ltd.
# UONE             -0.315203 -1.304338              Urban One, Inc.
# VNCE              0.862381  0.766672          Vince Holding Corp.
# WINA              0.166098  0.766672          Winmark Corporation
# XELB              0.181333  0.766672            Xcel Brands, Inc.
#
# [381 rows x 63 columns]

# %%
consumer_2018_ratios_final
# Out:
#         Net cash flow / Change in cash  Average Payables  Average Receivables  \
# Ticker
# CMCSA                         0.434656          2.432763             0.858468
# SIRI                         -0.065754          0.021661            -0.111580
# CZR                          -1.541373         -0.119710            -0.086995
# F                            -2.506642          7.542923            11.830484
# NKE                           0.581082          0.507762             0.222361
# ...                                ...               ...                  ...
# TKAT                         -0.080841         -0.243141            -0.134803
# UONE                         -0.077009         -0.228261            -0.124178
# VNCE                         -0.068010         -0.233980            -0.133691
# WINA                         -0.043837         -0.243740            -0.135074
# XELB                         -0.047800         -0.243223            -0.134267
#
#         currentRatio  SG&A to Revenue  daysOfPayablesOutstanding  \
# Ticker
# CMCSA      -0.721818         0.049681                  -0.051034
# SIRI       -1.151627        -0.077219                  -0.047671
# CZR        -0.485803        -0.071077                  -0.054814
# F          -0.439431        -0.120404                  -0.047074
# NKE         0.464484        -0.052569                  -0.053468
# ...              ...              ...                        ...
# TKAT       -0.172963         0.257943                   0.008058
# UONE       -0.193035        -0.023106                  -0.049993
# VNCE       -0.020003         0.002124                  -0.051670
# WINA        0.074818        -0.040729                  -0.057395
# XELB       -0.244944         0.050787                  -0.046118
#
#         daysOfInventoryOutstanding  eBITperRevenue  \
# Ticker
# CMCSA                    -0.047371        0.095818
# SIRI                     -0.049130        0.114464
# CZR                      -0.048793        0.093217
# F                        -0.032826        0.068101
# NKE                      -0.047859        0.082693
# ...                            ...             ...
# TKAT                     -0.032664       -0.088940
# UONE                     -0.044319        0.092810
# VNCE                     -0.048314        0.101921
# WINA                     -0.049563        0.160306
# XELB                     -0.042971        0.081074
#
#         Intangibles to Total Assets  Debt to Assets  Debt to Equity  \
# Ticker
# CMCSA                      1.825931        0.289072       -0.008118
# SIRI                       1.477677        1.425742       -0.181279
# CZR                        0.108227        1.129319        0.130982
# F                         -1.080549        0.736843        0.080267
# NKE                       -0.995450       -0.494456       -0.046045
# ...                             ...             ...             ...
# TKAT                      -1.076622       -0.686561       -0.050886
# UONE                       2.541641        1.125329        0.109975
# VNCE                       1.125059       -0.384722       -0.037541
# WINA                      -1.023816        0.785296       -0.252694
# XELB                       2.364459       -0.572267       -0.052268
#
#         Payout Ratio       ROE  R&D to Revenue  PE ratio  returnOnAssets  \
# Ticker
# CMCSA       0.042963 -0.042589       -0.063362 -0.137455       -0.015649
# SIRI       -0.064627 -0.369301       -0.052236 -0.007835       -0.275540
# CZR        -0.165238 -0.071030       -0.063362 -0.105562       -0.057896
# F           0.209873 -0.067364       -0.063362 -0.213410       -0.050788
# NKE         0.206383 -0.029214       -0.063362  0.566496       -0.039480
# ...              ...       ...             ...       ...             ...
# TKAT       -0.165238 -0.402255       -0.063362 -0.336521       -0.177498
# UONE       -0.165238  0.215760       -0.063362 -0.326398        0.177080
# VNCE       -0.165238  0.207139       -0.063362 -0.321866        0.067212
# WINA       -0.123365 -2.632482       -0.063362 -0.030258        0.293166
# XELB       -0.165238 -0.104185       -0.063362 -0.054653       -0.045921
#
#         Dividend Yield                         Name
# Ticker
# CMCSA         0.106519          Comcast Corporation
# SIRI         -0.239916      Sirius XM Holdings Inc.
# CZR          -0.383959  Caesars Entertainment, Inc.
# F             1.045538           Ford Motor Company
# NKE          -0.190685                   NIKE, Inc.
# ...                ...                          ...
# TKAT         -0.383959         Takung Art Co., Ltd.
# UONE         -0.383959              Urban One, Inc.
# VNCE         -0.383959          Vince Holding Corp.
# WINA         -0.320142          Winmark Corporation
# XELB         -0.383959            Xcel Brands, Inc.
#
# [417 rows x 18 columns]

# %%
# Export data to CSV file
consumer_2018_accounts_final.to_csv("../processed_data/2018_Data_Accounts.csv");

# %%
consumer_2018_ratios_final.to_csv("../processed_data/2018_Data_Ratios.csv");
