# %%
# import libraries
import pandas as pd;
import requests
from sklearn.preprocessing import StandardScaler

# %%
# read CSVs
financials_2018 = pd.read_csv('../data/2018_Financial_Data.csv');

# %%
# print all industries available
financials_2018.Sector.unique()
# Out:
# array(['Consumer Cyclical', 'Energy', 'Technology', 'Industrials',
#        'Financial Services', 'Basic Materials', 'Communication Services',
#        'Consumer Defensive', 'Healthcare', 'Real Estate', 'Utilities'],
#       dtype=object)

# %%
# clean up data
# we only want companies from the consumer packaged goods industry, "Consumer Cyclical".
# we can consider "Consumer Defensive" as well?
consumer_2018 = financials_2018.loc[financials_2018['Sector'] == "Consumer Cyclical"];

# %%
consumer_2018 = financials_2018

# %%
# add name for ticker column
consumer_2018.rename(columns={consumer_2018.columns[0]: "Ticker"}, inplace=True)
consumer_2018.set_index('Ticker', inplace=True)

# %%
pd.set_option('display.max_columns', 110)
pd.set_option('display.max_rows', 10)

# %%
# Remove specific keywords.
# Not used anymore, was used to isolate attributes.

#financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-5:] != 'ratio']
#financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'ratios']
financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-6:] != 'margin']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'turnover']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'growth']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-18:] != 'growth (per share)']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-9:] != 'per share']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'pershare']

# %%
# Select specific attributes from the consumer dataset
consumer_2018_accounts = consumer_2018[['Revenue',
                               'Cost of Revenue',
                               'Gross Profit',
                               'R&D Expenses',
                               'SG&A Expense',
                               'Operating Expenses',
                               'Operating Income',
                               'Interest Expense',
                               'Earnings before Tax',
                               'Income Tax Expense',
                               'Net Income',
                               'Preferred Dividends',
                               'Net Income Com',
                               'EBITDA',
                               'EBIT',
                               'Consolidated Income',
                               'Cash and cash equivalents',
                               'Short-term investments',
                               'Cash and short-term investments',
                               'Receivables',
                               'Inventories',
                               'Total current assets',
                               'Property, Plant & Equipment Net',
                               'Goodwill and Intangible Assets',
                               'Long-term investments',
                               'Tax assets',
                               'Total non-current assets',
                               'Total assets',
                               'Payables',
                               'Short-term debt',
                               'Total current liabilities',
                               'Long-term debt',
                               'Total debt',
                               'Deferred revenue',
                               'Tax Liabilities',
                               'Deposit Liabilities',
                               'Total non-current liabilities',
                               'Total liabilities',
                               'Other comprehensive income',
                               'Retained earnings (deficit)',
                               'Total shareholders equity',
                               'Investments',
                               'Net Debt',
                               'Other Assets',
                               'Other Liabilities',
                               'Depreciation & Amortization',
                               'Stock-based compensation',
                               'Operating Cash Flow',
                               'Capital Expenditure',
                               'Acquisitions and disposals',
                               'Investment purchases and sales',
                               'Investing Cash flow',
                               'Issuance (repayment) of debt',
                               'Issuance (buybacks) of shares',
                               'Dividend payments',
                               'Financing Cash Flow',
                               'Free Cash Flow',
                               'Market Cap',
                               'Enterprise Value',
                               'Working Capital',
                               '2019 PRICE VAR [%]',
                               'Class']]
consumer_2018_ratios = consumer_2018[['Net cash flow / Change in cash',
                                      'Average Payables',
                                      'Average Receivables',
                                      'currentRatio',
                                      'SG&A to Revenue',
                                      'daysOfPayablesOutstanding',
                                      'daysOfInventoryOutstanding',
                                      'eBITperRevenue',
                                      'Debt to Assets',
                                      'Debt to Equity',
                                      'Payout Ratio',
                                      'ROE',
                                      'R&D to Revenue',
                                      'PE ratio',
                                      'Dividend Yield']]

# %%
# Shows the rows that contain at least one nan
consumer_2018_accounts_nan_rows = consumer_2018_accounts[consumer_2018_accounts.isna().any(axis=1)]
consumer_2018_ratios_nan_rows = consumer_2018_ratios[consumer_2018_ratios.isna().any(axis=1)]

# %%
consumer_2018_ratios_nan_rows
# Out:
#         Net cash flow / Change in cash  Average Payables  Average Receivables  \
# Ticker
# AABA                      6.580000e+08               0.0         1.350000e+07
# HMY                      -4.214200e+07        41500000.0         7.400000e+07
# MFGP                      4.730000e+08        30500000.0         6.815000e+08
# DISCK                    -6.323000e+09               NaN                  NaN
# TS                        9.700000e+07       722500000.0         1.680500e+09
# ...                                ...               ...                  ...
# XBIO                     -4.961457e+06          860463.0         0.000000e+00
# XBIT                     -1.594500e+07         1691500.0         0.000000e+00
# XTLB                     -3.800000e+04          276500.0         0.000000e+00
# YRIV                      6.238200e+04        42683932.0         0.000000e+00
# ZOM                      -1.507882e+06         1602628.0         4.096550e+04
#
#         currentRatio  SG&A to Revenue  daysOfPayablesOutstanding  \
# Ticker
# AABA        6.312000              NaN                     0.0000
# HMY         1.164122           0.0396                     9.8773
# MFGP        1.249570           0.5565                     5.0662
# DISCK            NaN              NaN                        NaN
# TS          3.180442           0.1558                    33.0735
# ...              ...              ...                        ...
# XBIO        0.746000           0.0000                     0.0000
# XBIT        5.780000           0.0000                     0.0000
# XTLB       20.687000           0.0000                     0.0000
# YRIV             NaN           0.0000                     0.0000
# ZOM         1.625000           0.0000                     0.0000
#
#         daysOfInventoryOutstanding  eBITperRevenue  Debt to Assets  \
# Ticker
# AABA                        0.2238        0.011888          0.0270
# HMY                        17.6872        0.000000             NaN
# MFGP                      126.0804        0.000000             NaN
# DISCK                          NaN             NaN             NaN
# TS                         93.0729        0.000000             NaN
# ...                            ...             ...             ...
# XBIO                        0.0000             NaN          0.0000
# XBIT                        0.0000             NaN          0.0000
# XTLB                        0.0000             NaN          0.0000
# YRIV                        0.0000             NaN          0.3041
# ZOM                         0.0000             NaN          0.0000
#
#         Debt to Equity  Payout Ratio     ROE  R&D to Revenue  PE ratio  \
# Ticker
# AABA            0.0419           0.0     NaN             NaN    0.0000
# HMY                NaN           NaN     NaN             NaN       NaN
# MFGP               NaN           NaN     NaN          0.1350       NaN
# DISCK              NaN           NaN     NaN             NaN       NaN
# TS                 NaN           NaN     NaN          0.0082       NaN
# ...                ...           ...     ...             ...       ...
# XBIO            0.0000           0.0 -0.7365          0.0000    0.0000
# XBIT            0.0000           0.0 -0.5106          0.0000    0.0000
# XTLB            0.0000           0.0  0.3588          0.0000    2.8833
# YRIV            0.6850           0.0 -0.0800          0.0000    0.0000
# ZOM             0.0000           0.0 -4.5523          0.0000    0.0000
#
#         Dividend Yield
# Ticker
# AABA               0.0
# HMY                NaN
# MFGP               NaN
# DISCK              NaN
# TS                 NaN
# ...                ...
# XBIO               0.0
# XBIT               0.0
# XTLB               0.0
# YRIV               0.0
# ZOM                0.0
#
# [474 rows x 15 columns]

# %%
# Shows the number of nans in each column (accounts dataset)
consumer_2018_accounts.isnull().sum().sort_values()
# Out:
# Class                               0
# 2019 PRICE VAR [%]                  0
# Financing Cash Flow                19
# Retained earnings (deficit)        21
# Long-term debt                     30
#                                  ...
# Market Cap                        428
# Enterprise Value                  844
# Total non-current assets         1041
# Total non-current liabilities    1043
# Working Capital                  1103
# Length: 62, dtype: int64

# %%
# Shows the number of nans in each column (ratios dataset)
consumer_2018_ratios.isnull().sum().sort_values()
# Out:
# Net cash flow / Change in cash     24
# Average Receivables               125
# daysOfInventoryOutstanding        145
# Average Payables                  231
# daysOfPayablesOutstanding         234
#                                  ...
# Dividend Yield                    251
# PE ratio                          252
# Payout Ratio                      256
# ROE                               256
# eBITperRevenue                    347
# Length: 15, dtype: int64

# %%
# Drops the nan rows from the dataset
consumer_2018_accounts = consumer_2018_accounts.dropna()
consumer_2018_ratios = consumer_2018_ratios.dropna()

# %%
# Normalize Values
scaler = StandardScaler().fit(consumer_2018_accounts)
consumer_2018_accounts_scaled = scaler.transform(consumer_2018_accounts)

scaler = StandardScaler().fit(consumer_2018_ratios)
consumer_2018_ratios_scaled = scaler.transform(consumer_2018_ratios)

# %%
# Reconstruct Dataframe after normalization
consumer_2018_accounts_scaled = pd.DataFrame(consumer_2018_accounts_scaled, columns=consumer_2018_accounts.columns, index=consumer_2018_accounts.index)
consumer_2018_ratios_scaled = pd.DataFrame(consumer_2018_ratios_scaled, columns=consumer_2018_ratios.columns, index=consumer_2018_ratios.index)

# %%
consumer_2018_accounts
# Out:
#              Revenue  Cost of Revenue  Gross Profit  R&D Expenses  \
# Ticker
# CMCSA   9.450700e+10     0.000000e+00  9.450700e+10  0.000000e+00
# KMI     1.414400e+10     7.288000e+09  6.856000e+09  0.000000e+00
# INTC    7.084800e+10     2.711100e+10  4.373700e+10  1.354300e+10
# MU      3.039100e+10     1.250000e+10  1.789100e+10  2.141000e+09
# AAPL    2.655950e+11     1.637560e+11  1.018390e+11  1.423600e+10
# ...              ...              ...           ...           ...
# XBIT    0.000000e+00     0.000000e+00  0.000000e+00  1.572500e+07
# XELB    3.546600e+07     2.702000e+06  3.276400e+07  0.000000e+00
# YTEN    5.560000e+05     0.000000e+00  5.560000e+05  4.759000e+06
# ZOM     0.000000e+00     0.000000e+00  0.000000e+00  1.031715e+07
# ZYME    5.301900e+07     0.000000e+00  5.301900e+07  5.668400e+07
#
#         SG&A Expense  Operating Expenses  Operating Income  Interest Expense  \
# Ticker
# CMCSA   6.482200e+10        7.549800e+10      1.900900e+10      3.542000e+09
# KMI     6.010000e+08        3.062000e+09      3.794000e+09      1.917000e+09
# INTC    6.750000e+09        2.042100e+10      2.331600e+10     -1.260000e+08
# MU      8.130000e+08        2.897000e+09      1.499400e+10      3.420000e+08
# AAPL    1.670500e+10        3.094100e+10      7.089800e+10      0.000000e+00
# ...              ...                 ...               ...               ...
# XBIT    5.269000e+06        2.099400e+07     -2.099400e+07      0.000000e+00
# XELB    2.446700e+07        2.883400e+07      3.930000e+06      1.011000e+06
# YTEN    5.071000e+06        9.830000e+06     -9.274000e+06      0.000000e+00
# ZOM     4.521349e+06        1.664863e+07     -1.664863e+07      0.000000e+00
# ZYME    2.945700e+07        8.614600e+07     -3.312700e+07      1.660000e+05
#
#         Earnings before Tax  Income Tax Expense    Net Income  \
# Ticker
# CMCSA          1.511100e+10        3.380000e+09  1.173100e+10
# KMI            2.196000e+09        5.870000e+08  1.609000e+09
# INTC           2.331700e+10        2.264000e+09  2.105300e+10
# MU             1.430300e+10        1.680000e+08  1.413500e+10
# AAPL           7.290300e+10        1.337200e+10  5.953100e+10
# ...                     ...                 ...           ...
# XBIT          -2.113800e+07        0.000000e+00 -2.113800e+07
# XELB           2.919000e+06        1.831000e+06  1.088000e+06
# YTEN          -9.170000e+06        0.000000e+00 -9.170000e+06
# ZOM           -1.664769e+07        0.000000e+00 -1.664769e+07
# ZYME          -3.438500e+07        2.171000e+06 -3.655600e+07
#
#         Preferred Dividends  Net Income Com        EBITDA          EBIT  \
# Ticker
# CMCSA                   0.0    1.173100e+10  2.932900e+10  1.865300e+10
# KMI             128000000.0    1.481000e+09  6.410000e+09  4.113000e+09
# INTC                    0.0    2.105300e+10  3.227600e+10  2.319100e+10
# MU                      0.0    1.413500e+10  1.940400e+10  1.464500e+10
# AAPL                    0.0    5.953100e+10  8.380600e+10  7.290300e+10
# ...                     ...             ...           ...           ...
# XBIT                    0.0   -2.113800e+07 -1.870500e+07 -2.113800e+07
# XELB                    0.0    1.088000e+06  5.710000e+06  3.930000e+06
# YTEN                    0.0   -9.170000e+06 -8.974000e+06 -9.170000e+06
# ZOM                     0.0   -1.664769e+07 -1.644192e+07 -1.664769e+07
# ZYME                    0.0   -3.655600e+07 -3.058900e+07 -3.421900e+07
#
#         Consolidated Income  Cash and cash equivalents  \
# Ticker
# CMCSA          1.186200e+10               3.814000e+09
# KMI            1.919000e+09               3.280000e+09
# INTC           2.105300e+10               3.019000e+09
# MU             1.413800e+10               6.506000e+09
# AAPL           5.953100e+10               2.591300e+10
# ...                     ...                        ...
# XBIT          -2.113800e+07               1.582300e+07
# XELB           1.088000e+06               8.837000e+06
# YTEN          -9.170000e+06               3.355000e+06
# ZOM           -1.664769e+07               1.940265e+06
# ZYME          -3.655600e+07               4.220500e+07
#
#         Short-term investments  Cash and short-term investments   Receivables  \
# Ticker
# CMCSA             0.000000e+00                     3.814000e+09  1.110400e+10
# KMI               0.000000e+00                     3.280000e+09  1.498000e+09
# INTC              8.631000e+09                     1.165000e+10  6.722000e+09
# MU                2.960000e+08                     6.802000e+09  5.478000e+09
# AAPL              4.038800e+10                     6.630100e+10  4.899500e+10
# ...                        ...                              ...           ...
# XBIT              0.000000e+00                     1.582300e+07  0.000000e+00
# XELB              0.000000e+00                     8.837000e+06  1.101000e+07
# YTEN              2.746000e+06                     6.101000e+06  1.600000e+05
# ZOM               0.000000e+00                     1.940265e+06  5.365900e+04
# ZYME              1.579590e+08                     2.001640e+08  1.355000e+06
#
#          Inventories  Total current assets  Property, Plant & Equipment Net  \
# Ticker
# CMCSA   0.000000e+00          2.184800e+10                     4.443700e+10
# KMI     3.850000e+08          5.722000e+09                     3.789700e+10
# INTC    7.253000e+09          2.878700e+10                     4.897600e+10
# MU      3.595000e+09          1.603900e+10                     2.367200e+10
# AAPL    3.956000e+09          1.313390e+11                     4.130400e+10
# ...              ...                   ...                              ...
# XBIT    0.000000e+00          1.701600e+07                     2.732900e+07
# XELB    1.988000e+06          2.387500e+07                     3.202000e+06
# YTEN    0.000000e+00          6.377000e+06                     6.151000e+06
# ZOM     0.000000e+00          3.860958e+06                     7.170880e+05
# ZYME    0.000000e+00          2.043690e+08                     6.484000e+06
#
#         Goodwill and Intangible Assets  Long-term investments    Tax assets  \
# Ticker
# CMCSA                     1.676230e+11           7.883000e+09  0.000000e+00
# KMI                       2.484500e+10           7.481000e+09  1.566000e+09
# INTC                      3.634900e+10           9.430000e+09  0.000000e+00
# MU                        1.559000e+09           4.730000e+08  1.022000e+09
# AAPL                      0.000000e+00           1.707990e+11  0.000000e+00
# ...                                ...                    ...           ...
# XBIT                      0.000000e+00           0.000000e+00  0.000000e+00
# XELB                      1.089890e+08           1.482000e+06  0.000000e+00
# YTEN                      0.000000e+00           0.000000e+00  0.000000e+00
# ZOM                       1.305800e+04           0.000000e+00  0.000000e+00
# ZYME                      1.363000e+07           0.000000e+00  8.400000e+04
#
#         Total non-current assets  Total assets      Payables  Short-term debt  \
# Ticker
# CMCSA               2.298360e+11  2.516840e+11  8.494000e+09     4.398000e+09
# KMI                 7.314400e+10  7.886600e+10  1.337000e+09     3.388000e+09
# INTC                9.917600e+10  1.279630e+11  3.824000e+09     1.261000e+09
# MU                  2.733700e+10  4.337600e+10  4.374000e+09     8.590000e+08
# AAPL                2.343860e+11  3.657250e+11  5.588800e+10     2.074800e+10
# ...                          ...           ...           ...              ...
# XBIT                2.732900e+07  4.434500e+07  1.653000e+06     0.000000e+00
# XELB                1.141840e+08  1.380590e+08  5.140000e+06     8.275000e+06
# YTEN                6.583000e+06  1.296000e+07  1.170000e+05     8.440000e+05
# ZOM                 2.172561e+06  6.033519e+06  2.376519e+06     0.000000e+00
# ZYME                3.999400e+07  2.443630e+08  1.340300e+07     0.000000e+00
#
#         Total current liabilities  Long-term debt    Total debt  \
# Ticker
# CMCSA                2.760300e+10    1.073450e+11  1.117430e+11
# KMI                  7.557000e+09    3.393600e+10  3.732400e+10
# INTC                 1.662600e+10    2.509800e+10  2.635900e+10
# MU                   5.754000e+09    3.780000e+09  4.639000e+09
# AAPL                 1.159290e+11    9.373500e+10  1.144830e+11
# ...                           ...             ...           ...
# XBIT                 2.944000e+06    0.000000e+00  0.000000e+00
# XELB                 1.611600e+07    1.130000e+07  1.957500e+07
# YTEN                 1.641000e+06    5.621000e+06  6.465000e+06
# ZOM                  2.376519e+06    0.000000e+00  0.000000e+00
# ZYME                 2.998600e+07    0.000000e+00  0.000000e+00
#
#         Deferred revenue  Tax Liabilities  Deposit Liabilities  \
# Ticker
# CMCSA       2.182000e+09     2.758900e+10                  0.0
# KMI         0.000000e+00     4.830000e+08                  0.0
# INTC        0.000000e+00     6.562000e+09                  0.0
# MU          0.000000e+00     0.000000e+00                  0.0
# AAPL        5.966000e+09     0.000000e+00                  0.0
# ...                  ...              ...                  ...
# XBIT        0.000000e+00     0.000000e+00                  0.0
# XELB        0.000000e+00     8.139000e+06                  0.0
# YTEN        0.000000e+00     0.000000e+00                  0.0
# ZOM         0.000000e+00     0.000000e+00                  0.0
# ZYME        3.647100e+07     0.000000e+00                  0.0
#
#         Total non-current liabilities  Total liabilities  \
# Ticker
# CMCSA                    1.515790e+11       1.791820e+11
# KMI                      3.611200e+10       4.366900e+10
# INTC                     3.677400e+10       5.340000e+10
# MU                       4.358000e+09       1.011200e+10
# AAPL                     1.426490e+11       2.585780e+11
# ...                               ...                ...
# XBIT                     3.000000e+03       2.947000e+06
# XELB                     2.206100e+07       3.817700e+07
# YTEN                     5.621000e+06       7.262000e+06
# ZOM                      0.000000e+00       2.376519e+06
# ZYME                     3.388700e+07       6.387300e+07
#
#         Other comprehensive income  Retained earnings (deficit)  \
# Ticker
# CMCSA                -3.680000e+08                 4.198300e+10
# KMI                  -3.300000e+08                -7.716000e+09
# INTC                 -9.740000e+08                 5.017200e+10
# MU                    1.000000e+07                 2.439500e+10
# AAPL                 -3.454000e+09                 7.040000e+10
# ...                            ...                          ...
# XBIT                 -2.550000e+05                -2.377000e+08
# XELB                  0.000000e+00                -2.330000e+05
# YTEN                 -1.100000e+05                -3.519380e+08
# ZOM                   0.000000e+00                -3.227379e+07
# ZYME                 -6.659000e+06                -1.452720e+08
#
#         Total shareholders equity   Investments      Net Debt  Other Assets  \
# Ticker
# CMCSA                7.161300e+10  7.883000e+09  1.079290e+11  6.930000e+09
# KMI                  3.367800e+10  7.481000e+09  3.404400e+10  5.590000e+08
# INTC                 7.456300e+10  1.806100e+10  1.470900e+10  3.162000e+09
# MU                   3.229400e+10  7.690000e+08 -2.163000e+09  1.640000e+08
# AAPL                 1.071470e+11  2.111870e+11  4.818200e+10  1.208700e+10
# ...                           ...           ...           ...           ...
# XBIT                 4.139800e+07  0.000000e+00 -1.582300e+07  1.193000e+06
# XELB                 9.988200e+07  1.482000e+06  1.073800e+07  2.040000e+06
# YTEN                 5.698000e+06  2.746000e+06  3.640000e+05  1.160000e+05
# ZOM                  3.657000e+06  0.000000e+00 -1.940265e+06  1.867034e+06
# ZYME                 1.804900e+08  1.579590e+08 -2.001640e+08  2.850000e+06
#
#         Other Liabilities  Depreciation & Amortization  \
# Ticker
# CMCSA        1.471100e+10                 1.067600e+10
# KMI          2.832000e+09                 2.297000e+09
# INTC         1.154100e+10                 9.085000e+09
# MU           5.210000e+08                 4.759000e+09
# AAPL         3.929300e+10                 1.090300e+10
# ...                   ...                          ...
# XBIT         1.291000e+06                 2.433000e+06
# XELB         2.701000e+06                 1.780000e+06
# YTEN         6.800000e+05                 1.960000e+05
# ZOM          0.000000e+00                 2.057670e+05
# ZYME         1.658300e+07                 3.630000e+06
#
#         Stock-based compensation  Operating Cash Flow  Capital Expenditure  \
# Ticker
# CMCSA               8.260000e+08         2.429700e+10        -1.231200e+10
# KMI                 0.000000e+00         5.043000e+09        -2.924000e+09
# INTC                1.546000e+09         2.943200e+10        -1.518100e+10
# MU                  1.980000e+08         1.740000e+10        -8.879000e+09
# AAPL                5.340000e+09         7.743400e+10        -1.331300e+10
# ...                          ...                  ...                  ...
# XBIT                1.660000e+06        -1.653700e+07        -1.220000e+05
# XELB                1.788000e+06         6.593000e+06        -1.476000e+06
# YTEN                1.181000e+06        -8.754000e+06        -4.200000e+04
# ZOM                 5.658959e+06        -1.114753e+07        -6.189970e+05
# ZYME                1.344100e+07         2.417700e+07        -8.030000e+05
#
#         Acquisitions and disposals  Investment purchases and sales  \
# Ticker
# CMCSA                -3.807800e+10                   -1.257000e+09
# KMI                   2.928000e+09                   -7.200000e+07
# INTC                  3.580000e+08                    3.856000e+09
# MU                    0.000000e+00                    1.640000e+08
# AAPL                 -7.210000e+08                    3.084500e+10
# ...                            ...                             ...
# XBIT                  0.000000e+00                    0.000000e+00
# XELB                  0.000000e+00                    0.000000e+00
# YTEN                  0.000000e+00                   -2.746000e+06
# ZOM                   0.000000e+00                    0.000000e+00
# ZYME                  0.000000e+00                   -1.056260e+08
#
#         Investing Cash flow  Issuance (repayment) of debt  \
# Ticker
# CMCSA         -5.085400e+10                  3.636200e+10
# KMI           -6.800000e+07                  1.180000e+08
# INTC          -1.123900e+10                 -2.143000e+09
# MU            -8.216000e+09                 -9.185000e+09
# AAPL           1.606600e+10                  4.320000e+08
# ...                     ...                           ...
# XBIT          -1.220000e+05                  0.000000e+00
# XELB          -1.476000e+06                 -5.459000e+06
# YTEN          -2.788000e+06                  0.000000e+00
# ZOM           -6.189970e+05                  8.282496e+06
# ZYME          -1.090460e+08                 -1.100000e+04
#
#         Issuance (buybacks) of shares  Dividend payments  Financing Cash Flow  \
# Ticker
# CMCSA                   -5.320000e+09      -3.352000e+09         2.714000e+10
# KMI                     -2.730000e+08      -1.618000e+09        -1.824000e+09
# INTC                    -1.017500e+10      -5.541000e+09        -1.860700e+10
# MU                       1.584000e+09       0.000000e+00        -7.776000e+09
# AAPL                    -7.206900e+10      -1.371200e+10        -8.787600e+10
# ...                               ...                ...                  ...
# XBIT                     2.010000e+05       0.000000e+00         2.010000e+05
# XELB                    -1.033000e+06       0.000000e+00        -6.492000e+06
# YTEN                     1.240000e+05       0.000000e+00         1.180000e+05
# ZOM                      1.976147e+06       0.000000e+00         1.025864e+07
# ZYME                     9.166700e+07       0.000000e+00         9.143100e+07
#
#         Free Cash Flow    Market Cap  Enterprise Value  Working Capital  \
# Ticker
# CMCSA     1.198500e+10  1.549106e+11      2.628396e+11    -5.755000e+09
# KMI       2.119000e+09  3.394394e+10      6.798794e+10    -1.835000e+09
# INTC      1.425100e+10  2.141885e+11      2.288975e+11     1.216100e+10
# MU        8.521000e+09  6.119161e+10      5.902861e+10     1.028500e+10
# AAPL      6.412100e+10  1.097649e+12      1.145831e+12     1.541000e+10
# ...                ...           ...               ...              ...
# XBIT     -1.665900e+07  1.819644e+08      1.661414e+08     1.407200e+07
# XELB      5.117000e+06  2.066153e+07      3.139953e+07     7.759000e+06
# YTEN     -8.796000e+06  8.321423e+06      8.685423e+06     4.736000e+06
# ZOM      -1.176652e+07  1.165993e+08      1.146591e+08     1.484439e+06
# ZYME      2.337400e+07  4.692722e+08      2.691082e+08     1.743830e+08
#
#         2019 PRICE VAR [%]  Class
# Ticker
# CMCSA            32.794573      1
# KMI              40.588068      1
# INTC             30.295514      1
# MU               64.213737      1
# AAPL             88.742465      1
# ...                    ...    ...
# XBIT            262.427196      1
# XELB             27.118650      1
# YTEN            -77.922077      0
# ZOM             -73.520000      0
# ZYME            209.462222      1
#
# [2753 rows x 62 columns]

# %% [markdown]
# ### Yahoo Finance API
# ##### Used to convert ticker names to company names

# %%
def getCompanyName(ticker):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(ticker)

    result = requests.get(url).json()

    for x in result['ResultSet']['Result']:
        if x['symbol'] == ticker:
            return x['name']

# %% [markdown]
# ##### Calls the Yahoo API. Only run if necessary. Takes a minute or two to get all the data from Yahoo servers.

# %%
consumer_2018_accounts_final = consumer_2018_accounts_scaled
consumer_2018_accounts_final['Name'] = consumer_2018_accounts_final.apply(lambda row : getCompanyName(row.name), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9fc3b8addfa6> in <module>
#       1 consumer_2018_accounts_final = consumer_2018_accounts_scaled
# ----> 2 consumer_2018_accounts_final['Name'] = consumer_2018_accounts_final.apply(lambda row : getCompanyName(row.name), axis = 1)
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-24-9fc3b8addfa6> in <lambda>(row)
#       1 consumer_2018_accounts_final = consumer_2018_accounts_scaled
# ----> 2 consumer_2018_accounts_final['Name'] = consumer_2018_accounts_final.apply(lambda row : getCompanyName(row.name), axis = 1)
#
# <ipython-input-23-5d9db539af7b> in getCompanyName(ticker)
#       2     url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(ticker)
#       3
# ----> 4     result = requests.get(url).json()
#       5
#       6     for x in result['ResultSet']['Result']:
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\users\trieu\appdata\local\programs\python\python38\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
consumer_2018_ratios_final = consumer_2018_ratios_scaled
consumer_2018_ratios_final['Name'] = consumer_2018_ratios_final.apply(lambda row : getCompanyName(row.name), axis = 1)

# %% [markdown]
# ##### Removes Tickers that are not found on Yahoo Finance

# %%
#consumer_2018_accounts_final = consumer_2018_accounts_final[consumer_2018_accounts_final['Name'].isnull() == False]
consumer_2018_ratios_final = consumer_2018_ratios_final[consumer_2018_ratios_final['Name'].isnull() == False]

# %% [markdown]
# ### Consumer 2018 Dataset with only accounts

# %%
consumer_2018_accounts_final
# Out:
#           Revenue  Cost of Revenue  Gross Profit  R&D Expenses  SG&A Expense  \
# Ticker
# CMCSA    4.555891        -0.222696     13.569116     -0.130696     18.326385
# KMI      0.467488         0.284005      0.747107     -0.130696     -0.059557
# INTC     3.352258         1.662206      6.142237     13.357659      1.700851
# MU       1.294041         0.646371      2.361360      2.001665      0.001137
# AAPL    13.259856        11.162498     14.641676     14.047862      4.550885
# ...           ...              ...           ...           ...           ...
# XBIT    -0.252077        -0.222696     -0.255821     -0.115034     -0.230110
# XELB    -0.250273        -0.222508     -0.251028     -0.130696     -0.224613
# YTEN    -0.252049        -0.222696     -0.255740     -0.125956     -0.230166
# ZOM     -0.252077        -0.222696     -0.255821     -0.120420     -0.230324
# ZYME    -0.249380        -0.222696     -0.248065     -0.074240     -0.223185
#
#         Operating Expenses  Operating Income  Interest Expense  \
# Ticker
# CMCSA            15.196296          7.391134         11.678015
# KMI               0.376477          1.306234          6.183111
# INTC              3.927988          9.113623         -0.725252
# MU                0.342719          5.785424          0.857281
# AAPL              6.080294         28.142983         -0.299185
# ...                    ...               ...               ...
# XBIT             -0.245688         -0.219488         -0.299185
# XELB             -0.244084         -0.209520         -0.295767
# YTEN             -0.247972         -0.214801         -0.299185
# ZOM              -0.246577         -0.217750         -0.299185
# ZYME             -0.232359         -0.224340         -0.298624
#
#         Earnings before Tax  Income Tax Expense  Net Income  \
# Ticker
# CMCSA              5.904277            4.510684    5.734022
# KMI                0.698688            0.675743    0.628001
# INTC               9.211830            2.978355   10.436484
# MU                 5.578600            0.100433    6.946714
# AAPL              29.198225           18.230245   29.846627
# ...                     ...                 ...         ...
# XBIT              -0.194963           -0.130240   -0.194318
# XELB              -0.185266           -0.127726   -0.183106
# YTEN              -0.190139           -0.130240   -0.188281
# ZOM               -0.193153           -0.130240   -0.192053
# ZYME              -0.200302           -0.127259   -0.202096
#
#         Preferred Dividends  Net Income Com     EBITDA       EBIT  \
# Ticker
# CMCSA             -0.116386        5.732964   7.978721   6.946647
# KMI                7.047325        0.563655   1.562325   1.367150
# INTC              -0.116386       10.434261   8.803762   8.688033
# MU                -0.116386        6.945356   5.200121   5.408639
# AAPL              -0.116386       29.839593  23.230083  27.764233
# ...                     ...             ...        ...        ...
# XBIT              -0.116386       -0.193907  -0.237453  -0.219261
# XELB              -0.116386       -0.182698  -0.230617  -0.209642
# YTEN              -0.116386       -0.187871  -0.234728  -0.214669
# ZOM               -0.116386       -0.191643  -0.236819  -0.217538
# ZYME              -0.116386       -0.201683  -0.240780  -0.224281
#
#         Consolidated Income  Cash and cash equivalents  \
# Ticker
# CMCSA              5.757174                   1.127146
# KMI                0.775191                   0.946902
# INTC              10.362365                   0.858806
# MU                 6.897574                   2.035792
# AAPL              29.641935                   8.586345
# ...                     ...                        ...
# XBIT              -0.196924                  -0.154873
# XELB              -0.185787                  -0.157231
# YTEN              -0.190927                  -0.159082
# ZOM               -0.194674                  -0.159559
# ZYME              -0.204649                  -0.145968
#
#         Short-term investments  Cash and short-term investments  Receivables  \
# Ticker
# CMCSA                -0.095234                         0.691104     3.042325
# KMI                  -0.095234                         0.571629     0.241407
# INTC                  3.195212                         2.444299     1.764621
# MU                    0.017612                         1.359627     1.401895
# AAPL                 15.302113                        14.671699    14.090584
# ...                        ...                              ...          ...
# XBIT                 -0.095234                        -0.158685    -0.195380
# XELB                 -0.095234                        -0.160248    -0.192170
# YTEN                 -0.094187                        -0.160861    -0.195333
# ZOM                  -0.095234                        -0.161791    -0.195364
# ZYME                 -0.035014                        -0.117442    -0.194985
#
#         Inventories  Total current assets  Property, Plant & Equipment Net  \
# Ticker
# CMCSA     -0.041423              2.570626                         4.430294
# KMI       -0.019391              0.486669                         3.745109
# INTC       0.373622              3.467350                         4.905837
# MU         0.164297              1.819931                         2.254780
# AAPL       0.184955             16.720107                         4.102055
# ...             ...                   ...                              ...
# XBIT      -0.041423             -0.250584                        -0.222432
# XELB      -0.041309             -0.249697                        -0.224960
# YTEN      -0.041423             -0.251959                        -0.224651
# ZOM       -0.041423             -0.252284                        -0.225220
# ZYME      -0.041423             -0.226372                        -0.224616
#
#         Goodwill and Intangible Assets  Long-term investments  Tax assets  \
# Ticker
# CMCSA                        17.231965               2.021300   -0.114634
# KMI                           2.378676               1.913976    2.534975
# INTC                          3.575445               2.434309   -0.114634
# MU                           -0.043782               0.043021    1.614549
# AAPL                         -0.205966              45.515678   -0.114634
# ...                                ...                    ...         ...
# XBIT                         -0.205966              -0.083258   -0.114634
# XELB                         -0.194628              -0.082863   -0.114634
# YTEN                         -0.205966              -0.083258   -0.114634
# ZOM                          -0.205965              -0.083258   -0.114634
# ZYME                         -0.204548              -0.083258   -0.114492
#
#         Total non-current assets  Total assets   Payables  Short-term debt  \
# Ticker
# CMCSA                  11.790839      9.933827   2.951895         2.313346
# KMI                     3.577136      2.921229   0.287846         1.748378
# INTC                    4.941718      4.913484   1.213582         0.558588
# MU                      1.175960      1.481118   1.418308         0.333720
# AAPL                   12.029348     14.561376  20.593362        11.459120
# ...                          ...           ...        ...              ...
# XBIT                   -0.255597     -0.277191  -0.209210        -0.146783
# XELB                   -0.251044     -0.273389  -0.207912        -0.142154
# YTEN                   -0.256684     -0.278465  -0.209782        -0.146311
# ZOM                    -0.256916     -0.278746  -0.208941        -0.146783
# ZYME                   -0.254933     -0.269075  -0.204837        -0.146783
#
#         Total current liabilities  Long-term debt  Total debt  \
# Ticker
# CMCSA                    4.334317       14.234994   12.825053
# KMI                      1.009469        4.310710    4.103171
# INTC                     2.513662        3.115886    2.818076
# MU                       0.710422        0.233871    0.272499
# AAPL                    18.984147       12.395036   13.146180
# ...                           ...             ...         ...
# XBIT                    -0.243453       -0.277154   -0.271190
# XELB                    -0.241269       -0.275626   -0.268896
# YTEN                    -0.243669       -0.276394   -0.270432
# ZOM                     -0.243547       -0.277154   -0.271190
# ZYME                    -0.238968       -0.277154   -0.271190
#
#         Deferred revenue  Tax Liabilities  Deposit Liabilities  \
# Ticker
# CMCSA           1.546034        13.324159            -0.037633
# KMI            -0.096421         0.067838            -0.037633
# INTC           -0.096421         3.040803            -0.037633
# MU             -0.096421        -0.168375            -0.037633
# AAPL            4.394361        -0.168375            -0.037633
# ...                  ...              ...                  ...
# XBIT           -0.096421        -0.168375            -0.037633
# XELB           -0.096421        -0.164395            -0.037633
# YTEN           -0.096421        -0.168375            -0.037633
# ZOM            -0.096421        -0.168375            -0.037633
# ZYME           -0.068969        -0.168375            -0.037633
#
#         Total non-current liabilities  Total liabilities  \
# Ticker
# CMCSA                       13.185216          10.731086
# KMI                          2.941102           2.408504
# INTC                         2.999834           3.006137
# MU                           0.123920           0.347589
# AAPL                        12.392955          15.607222
# ...                               ...                ...
# XBIT                        -0.262717          -0.273263
# XELB                        -0.260760          -0.271099
# YTEN                        -0.262218          -0.272998
# ZOM                         -0.262717          -0.273298
# ZYME                        -0.259711          -0.269521
#
#         Other comprehensive income  Retained earnings (deficit)  \
# Ticker
# CMCSA                    -0.119215                     3.417826
# KMI                      -0.088341                    -0.794610
# INTC                     -0.611569                     4.111917
# MU                        0.187897                     1.927085
# AAPL                     -2.626483                     5.826421
# ...                            ...                          ...
# XBIT                      0.179566                    -0.160757
# XELB                      0.179773                    -0.140629
# YTEN                      0.179683                    -0.170440
# ZOM                       0.179773                    -0.143345
# ZYME                      0.174363                    -0.152923
#
#         Total shareholders equity  Investments   Net Debt  Other Assets  \
# Ticker
# CMCSA                    7.274738     1.383365  14.080470      0.405738
# KMI                      3.291331     1.307285   4.297299      0.041497
# INTC                     7.584506     3.309579   1.737136      0.190315
# MU                       3.146003     0.037022  -0.496898      0.018914
# AAPL                    11.006025    39.859186   6.169323      0.700572
# ...                           ...          ...        ...           ...
# XBIT                    -0.240718    -0.108514  -0.212589      0.009606
# XELB                    -0.234576    -0.108233  -0.209072      0.009654
# YTEN                    -0.244466    -0.107994  -0.210446      0.009544
# ZOM                     -0.244681    -0.108514  -0.210751      0.009644
# ZYME                    -0.226112    -0.078619  -0.236998      0.009700
#
#         Other Liabilities  Depreciation & Amortization  \
# Ticker
# CMCSA            4.697254                     8.676553
# KMI              0.730494                     1.683901
# INTC             3.638694                     7.348792
# MU              -0.041219                     3.738551
# AAPL            12.905932                     8.865994
# ...                   ...                          ...
# XBIT            -0.214766                    -0.231018
# XELB            -0.214295                    -0.231563
# YTEN            -0.214970                    -0.232885
# ZOM             -0.215197                    -0.232876
# ZYME            -0.209659                    -0.230019
#
#         Stock-based compensation  Operating Cash Flow  Capital Expenditure  \
# Ticker
# CMCSA                   2.888955             7.573430            -9.314869
# KMI                    -0.156165             1.392297            -2.029719
# INTC                    5.543297             9.221925           -11.541232
# MU                      0.573779             5.359278            -6.650838
# AAPL                   19.530203            24.632060           -10.091652
# ...                          ...                  ...                  ...
# XBIT                   -0.150045            -0.231972             0.239230
# XELB                   -0.149573            -0.224546             0.238179
# YTEN                   -0.151811            -0.229473             0.239292
# ZOM                    -0.135303            -0.230242             0.238844
# ZYME                   -0.106613            -0.218901             0.238701
#
#         Acquisitions and disposals  Investment purchases and sales  \
# Ticker
# CMCSA                   -23.452420                       -1.358390
# KMI                       1.917555                       -0.130042
# INTC                      0.327523                        3.941647
# MU                        0.106033                        0.114591
# AAPL                     -0.340042                       31.917926
# ...                            ...                             ...
# XBIT                      0.106033                       -0.055408
# XELB                      0.106033                       -0.055408
# YTEN                      0.106033                       -0.058254
# ZOM                       0.106033                       -0.055408
# ZYME                      0.106033                       -0.164898
#
#         Investing Cash flow  Issuance (repayment) of debt  \
# Ticker
# CMCSA            -20.679676                     25.466337
# KMI                0.146460                      0.031409
# INTC              -4.434502                     -1.555291
# MU                -3.194842                     -6.497151
# AAPL               6.762632                      0.251765
# ...                     ...                           ...
# XBIT               0.174295                     -0.051399
# XELB               0.173740                     -0.055230
# YTEN               0.173202                     -0.051399
# ZOM                0.174092                     -0.045587
# ZYME               0.129628                     -0.051407
#
#         Issuance (buybacks) of shares  Dividend payments  Financing Cash Flow  \
# Ticker
# CMCSA                       -2.911846          -3.960724             5.313459
# KMI                         -0.040450          -1.809499            -0.311133
# INTC                        -5.674007          -6.676428            -3.570266
# MU                           1.016056           0.197815            -1.466967
# AAPL                       -40.887436         -16.813486           -17.021788
# ...                               ...                ...                  ...
# XBIT                         0.114983           0.197815             0.043113
# XELB                         0.114281           0.197815             0.041813
# YTEN                         0.114939           0.197815             0.043097
# ZOM                          0.115993           0.197815             0.045066
# ZYME                         0.167021           0.197815             0.060829
#
#         Free Cash Flow  Market Cap  Enterprise Value  Working Capital  \
# Ticker
# CMCSA         5.450612    3.597664          5.924787        -1.675550
# KMI           0.809327    0.624903          1.356831        -0.620405
# INTC          6.516612    5.054420          5.129074         3.146896
# MU            3.821035    1.294515          1.146796         2.641933
# AAPL         29.977071   26.765492         26.624967         4.021428
# ...                ...         ...               ...              ...
# XBIT         -0.195356   -0.204799         -0.233131        -0.122690
# XELB         -0.185112   -0.208763         -0.236290        -0.124390
# YTEN         -0.191657   -0.209066         -0.236823        -0.125203
# ZOM          -0.193055   -0.206405         -0.234338        -0.126078
# ZYME         -0.176523   -0.197738         -0.230718        -0.079539
#
#         2019 PRICE VAR [%]     Class
# Ticker
# CMCSA             0.125473  0.750544
# KMI               0.206113  0.750544
# INTC              0.099615  0.750544
# MU                0.450570  0.750544
# AAPL              0.704371  0.750544
# ...                    ...       ...
# XBIT              2.501505  0.750544
# XELB              0.066743  0.750544
# YTEN             -1.020124 -1.332367
# ZOM              -0.974575 -1.332367
# ZYME              1.953471  0.750544
#
# [2753 rows x 62 columns]

# %%
consumer_2018_ratios_final
# Out:
#         Net cash flow / Change in cash  Average Payables  Average Receivables  \
# Ticker
# CMCSA                         0.118923          0.473944             1.638677
# KMI                           0.942280          0.012576             0.094058
# INTC                         -0.113235          0.160323             0.946998
# MU                            0.437831          0.206949             0.665927
# GE                           -2.818243          0.982517             6.219718
# ...                                ...               ...                  ...
# WVVI                          0.013329         -0.084326            -0.173367
# XELB                          0.014151         -0.084251            -0.171965
# YTEN                          0.011041         -0.084476            -0.173716
# ZKIN                          0.013465         -0.083976            -0.167377
# ZYME                          0.016508         -0.083669            -0.173406
#
#         currentRatio  SG&A to Revenue  daysOfPayablesOutstanding  \
# Ticker
# CMCSA      -0.356853        -0.044034                  -0.066821
# KMI        -0.363241        -0.060170                  -0.066377
# INTC       -0.185465        -0.058846                  -0.070255
# MU          0.007278        -0.060563                  -0.061652
# GE         -0.187800        -0.057501                  -0.064205
# ...              ...              ...                        ...
# WVVI        0.467234        -0.049720                  -0.067693
# XELB       -0.231096        -0.043934                  -0.061556
# YTEN        0.207870         0.167490                  -0.055292
# ZKIN       -0.201344        -0.058028                  -0.066069
# ZYME        0.742477        -0.047302                  -0.051240
#
#         daysOfInventoryOutstanding  eBITperRevenue  Debt to Assets  \
# Ticker
# CMCSA                    -0.026435        0.050575        0.337676
# KMI                      -0.027191        0.051445        0.396621
# INTC                     -0.027910        0.051786       -0.141131
# MU                       -0.022345        0.053225       -0.340499
# GE                       -0.018289        0.047457        0.114367
# ...                            ...             ...             ...
# WVVI                     -0.027449        0.050511       -0.282157
# XELB                     -0.013858        0.049769       -0.270288
# YTEN                     -0.015336       -0.104876        0.447922
# ZKIN                      0.010571        0.050375       -0.048186
# ZYME                     -0.032428        0.042726       -0.555560
#
#         Debt to Equity  Payout Ratio       ROE  R&D to Revenue  PE ratio  \
# Ticker
# CMCSA         0.055796      0.010642 -0.015926       -0.049350 -0.108544
# KMI           0.022762      0.152212 -0.015927       -0.049350 -0.016143
# INTC         -0.032390     -0.007532 -0.015925       -0.046837 -0.136551
# MU           -0.047726     -0.057847 -0.015925       -0.048425 -0.191694
# GE            0.186120     -0.084821 -0.015931       -0.049350 -0.231417
# ...                ...           ...       ...             ...       ...
# WVVI         -0.045388     -0.057847 -0.015927       -0.049350 -0.059390
# XELB         -0.043898     -0.057847 -0.015927       -0.049350 -0.057434
# YTEN          0.024684     -0.057847 -0.015936        0.063150 -0.231417
# ZKIN         -0.020209     -0.057847 -0.015926       -0.048954 -0.174568
# ZYME         -0.058219     -0.057847 -0.015928       -0.035298 -0.231417
#
#         Dividend Yield                               Name
# Ticker
# CMCSA         0.033407                Comcast Corporation
# KMI           0.213109                Kinder Morgan, Inc.
# INTC          0.021842                  Intel Corporation
# MU           -0.205898            Micron Technology, Inc.
# GE            0.246024           General Electric Company
# ...                ...                                ...
# WVVI         -0.205898  Willamette Valley Vineyards, Inc.
# XELB         -0.205898                  Xcel Brands, Inc.
# YTEN         -0.205898           Yield10 Bioscience, Inc.
# ZKIN         -0.205898   ZK International Group Co., Ltd.
# ZYME         -0.205898                     Zymeworks Inc.
#
# [3580 rows x 16 columns]

# %%
# Export data to CSV file
consumer_2018_accounts_final.to_csv("../processed_data/2018_Data_Accounts.csv");

# %%
consumer_2018_ratios_final.to_csv("../processed_data/2018_Data_Ratios_All.csv");
