# %%
import numpy  as np
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import AffinityPropagation

# %%
df = pd.read_csv("../processed_data/2018_Data_Ratios.csv")

# convert 'Name' column into row indices
df.set_index('Name', inplace=True)

# remove ticker column
df_ticker = df['Ticker']
df = df.drop(columns=['Ticker'])

# display
display(df)
# Out:
#                              Net cash flow / Change in cash  Average Payables  \
# Name
# Comcast Corporation                                0.434656          2.432763
# Sirius XM Holdings Inc.                           -0.065754          0.021661
# Caesars Entertainment, Inc.                       -1.541373         -0.119710
# Ford Motor Company                                -2.506642          7.542923
# NIKE, Inc.                                         0.581082          0.507762
# ...                                                     ...               ...
# Takung Art Co., Ltd.                              -0.080841         -0.243141
# Urban One, Inc.                                   -0.077009         -0.228261
# Vince Holding Corp.                               -0.068010         -0.233980
# Winmark Corporation                               -0.043837         -0.243740
# Xcel Brands, Inc.                                 -0.047800         -0.243223
#
#                              Average Receivables  currentRatio  \
# Name
# Comcast Corporation                     0.858468     -0.721818
# Sirius XM Holdings Inc.                -0.111580     -1.151627
# Caesars Entertainment, Inc.            -0.086995     -0.485803
# Ford Motor Company                     11.830484     -0.439431
# NIKE, Inc.                              0.222361      0.464484
# ...                                          ...           ...
# Takung Art Co., Ltd.                   -0.134803     -0.172963
# Urban One, Inc.                        -0.124178     -0.193035
# Vince Holding Corp.                    -0.133691     -0.020003
# Winmark Corporation                    -0.135074      0.074818
# Xcel Brands, Inc.                      -0.134267     -0.244944
#
#                              SG&A to Revenue  daysOfPayablesOutstanding  \
# Name
# Comcast Corporation                 0.049681                  -0.051034
# Sirius XM Holdings Inc.            -0.077219                  -0.047671
# Caesars Entertainment, Inc.        -0.071077                  -0.054814
# Ford Motor Company                 -0.120404                  -0.047074
# NIKE, Inc.                         -0.052569                  -0.053468
# ...                                      ...                        ...
# Takung Art Co., Ltd.                0.257943                   0.008058
# Urban One, Inc.                    -0.023106                  -0.049993
# Vince Holding Corp.                 0.002124                  -0.051670
# Winmark Corporation                -0.040729                  -0.057395
# Xcel Brands, Inc.                   0.050787                  -0.046118
#
#                              daysOfInventoryOutstanding  eBITperRevenue  \
# Name
# Comcast Corporation                           -0.047371        0.095818
# Sirius XM Holdings Inc.                       -0.049130        0.114464
# Caesars Entertainment, Inc.                   -0.048793        0.093217
# Ford Motor Company                            -0.032826        0.068101
# NIKE, Inc.                                    -0.047859        0.082693
# ...                                                 ...             ...
# Takung Art Co., Ltd.                          -0.032664       -0.088940
# Urban One, Inc.                               -0.044319        0.092810
# Vince Holding Corp.                           -0.048314        0.101921
# Winmark Corporation                           -0.049563        0.160306
# Xcel Brands, Inc.                             -0.042971        0.081074
#
#                              Intangibles to Total Assets  Debt to Assets  \
# Name
# Comcast Corporation                             1.825931        0.289072
# Sirius XM Holdings Inc.                         1.477677        1.425742
# Caesars Entertainment, Inc.                     0.108227        1.129319
# Ford Motor Company                             -1.080549        0.736843
# NIKE, Inc.                                     -0.995450       -0.494456
# ...                                                  ...             ...
# Takung Art Co., Ltd.                           -1.076622       -0.686561
# Urban One, Inc.                                 2.541641        1.125329
# Vince Holding Corp.                             1.125059       -0.384722
# Winmark Corporation                            -1.023816        0.785296
# Xcel Brands, Inc.                               2.364459       -0.572267
#
#                              Debt to Equity  Payout Ratio       ROE  \
# Name
# Comcast Corporation               -0.008118      0.042963 -0.042589
# Sirius XM Holdings Inc.           -0.181279     -0.064627 -0.369301
# Caesars Entertainment, Inc.        0.130982     -0.165238 -0.071030
# Ford Motor Company                 0.080267      0.209873 -0.067364
# NIKE, Inc.                        -0.046045      0.206383 -0.029214
# ...                                     ...           ...       ...
# Takung Art Co., Ltd.              -0.050886     -0.165238 -0.402255
# Urban One, Inc.                    0.109975     -0.165238  0.215760
# Vince Holding Corp.               -0.037541     -0.165238  0.207139
# Winmark Corporation               -0.252694     -0.123365 -2.632482
# Xcel Brands, Inc.                 -0.052268     -0.165238 -0.104185
#
#                              R&D to Revenue  PE ratio  returnOnAssets  \
# Name
# Comcast Corporation               -0.063362 -0.137455       -0.015649
# Sirius XM Holdings Inc.           -0.052236 -0.007835       -0.275540
# Caesars Entertainment, Inc.       -0.063362 -0.105562       -0.057896
# Ford Motor Company                -0.063362 -0.213410       -0.050788
# NIKE, Inc.                        -0.063362  0.566496       -0.039480
# ...                                     ...       ...             ...
# Takung Art Co., Ltd.              -0.063362 -0.336521       -0.177498
# Urban One, Inc.                   -0.063362 -0.326398        0.177080
# Vince Holding Corp.               -0.063362 -0.321866        0.067212
# Winmark Corporation               -0.063362 -0.030258        0.293166
# Xcel Brands, Inc.                 -0.063362 -0.054653       -0.045921
#
#                              Dividend Yield
# Name
# Comcast Corporation                0.106519
# Sirius XM Holdings Inc.           -0.239916
# Caesars Entertainment, Inc.       -0.383959
# Ford Motor Company                 1.045538
# NIKE, Inc.                        -0.190685
# ...                                     ...
# Takung Art Co., Ltd.              -0.383959
# Urban One, Inc.                   -0.383959
# Vince Holding Corp.               -0.383959
# Winmark Corporation               -0.320142
# Xcel Brands, Inc.                 -0.383959
#
# [417 rows x 17 columns]

# %%
random_state = 0
af = AffinityPropagation(preference=-100).fit(df)
cluster_centers_indices = af.cluster_centers_indices_
labels = af.labels_
labels_pred = af.predict(df)
# Out:
# C:\Users\jkeho\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:146: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 0.25 which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(("'random_state' has been introduced in 0.23. "

# %%
n_clusters_ = len(cluster_centers_indices)
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 21

# %%
'''first couple labels aren't really relevant'''
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_pred, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_pred, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_pred, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_pred, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_pred, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(df, labels, metric='sqeuclidean'))
# Out:
# Homogeneity: 1.000
# Completeness: 1.000
# V-measure: 1.000
# Adjusted Rand Index: 1.000
# Adjusted Mutual Information: 1.000
# Silhouette Coefficient: 0.592

# %%
from itertools import cycle

# %%
frame = pd.DataFrame(df)
frame['cluster'] = labels
frame['cluster'].value_counts()
# Out:
# 4     106
# 9      88
# 7      81
# 10     57
# 11     45
# 1       9
# 15      6
# 16      4
# 2       3
# 3       3
# 12      3
# 0       2
# 13      2
# 8       1
# 19      1
# 6       1
# 5       1
# 14      1
# 17      1
# 18      1
# 20      1
#   -3.83959294e-01  1.90000000e+01]
#  [-4.49965013e-02 -2.44215360e-01 -1.35095927e-01 -6.06232897e-01
#    2.55909638e+00  2.96835127e-02  1.03480582e-01 -3.82810671e+00
#   -1.26996772e-01 -3.93272487e-01 -2.65589411e-02 -1.65238073e-01
#   -3.46582123e+00  5.47738090e-01 -3.36520876e-01  2.12005890e+01
#   -3.83959294e-01  2.00000000e+01]
#  [-4.49628790e-02 -2.43144071e-01 -1.33932114e-01 -1.18138835e+00
#    7.27809725e-02  2.14061452e+01  2.14235542e+01  7.83638245e-02
#    1.45542046e+00 -2.19123607e-01  2.82209932e-02 -1.47376358e+00
#   -1.08696579e-01 -6.33623813e-02 -3.36520876e-01 -6.06409155e-02
#    1.01271756e+00  2.10000000e+01]
#  [-4.99983271e-02 -2.44095373e-01 -1.35240438e-01  2.14453270e-03
#    2.07534464e+01  6.15076759e-01 -5.00511581e-02 -1.95719654e+01
#   -1.08054935e+00 -5.06751804e-02 -4.02595875e-02 -1.65238073e-01
#   -6.60442316e-01  2.08150719e+01 -3.36520876e-01 -2.32120637e-01
#   -3.83959294e-01  2.20000000e+01]]

# %%
print(af.labels_) # respective cluster for each company (company at index 1 is in cluster 1)
# Out:
# [ 1  7 10  0  4  2  2  1 11  9 10  1 10  9  9  3  9 11 15 10  7  4  2 10
#   1 10  9  1  4  9 10  9 10  7  7 11  4 11  9  4  9  4  4  9  9  9  9  9
#  10 10  7  4  1  4  4  9  4  9 10  3  7  7  9  7  9  4  4 11  4  7 11 12
#   9 11  4  4  7 15  9 11 10 10  4  5 10  7  7  7  7  4  7  9  6  7  4 15
#   7  9 10  9 11 11  9  4  4  7  4  7 10  4 10  4  1  9  9 10  7  9  9  4
#   3  1  4 10 10 10  4  9  7  4  7  4  7  4  9  9 10 10 11  7 10  4  7 10
#   4  7  9 11  9  9  9  4  7  4 10  4  9 15 10  4  7  4  7  9  7  9  9 10
#  10  9  4  4  4  4  4  9  9  7  4  7  9  9  7  7  9  4  4 11 11 10 10  7
#   8  4 11  4  4  7 10  9  7  4  4  9  9  9  9  4  7  4  9 10  7 11  7  9
#   9  4  9  9  9 10  4  9  1 10  7  7  4  7  4  9  9 11  7  9  4 11  4 10
#   7  4  7  9 11  9  7  7 11 10  4 11 10  0 10 10  9  4  9 10  7  7  7  4
#   7 11 10  7 15  4  7  7 10  7  7  7  7 12  4  9 11  7  7  7 10  9 10  4
#   4  4  7  9 10  9  9  4 11 11  9  7  4  7  9 11  9  4  9  4  4  7 10  7
#   4  9 10  9  9 10  7  9 11 12  9 16  4  4 11 13  4  7  9 14 10  4 11  4
#  15 11  7  9 11  9  7  9  9 10 11  4 11  7 16  4 16  4  4 17  4 11  7  4
#   9  7 10  4  4 11  4  9  4 10 11 11 10  9 11  4  4  4 18 11  4 13  4  4
#   4  4 10  4 11 11  4  7 11  4 19  4  4 20  7  9  7  4 11  9  7  4  4 16
#  10 11 11  4  4  7  7 10  7]

# %%
df.to_csv("../processed_data/2018_Clusters_Ratios_AF.csv");

# %%
df_clusters_only = df[['cluster']]
df_clusters_only = df_clusters_only.reset_index()
df_clusters_only['ticker'] = df_ticker.to_numpy()
df_clusters_only = df_clusters_only.rename(columns={"Name": "name"})
df_clusters_only.to_json (r'../processed_data/2018_Clusters_Ratios_AF.json', orient='records')
