# %%
import numpy  as np
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import AffinityPropagation

# %%
df = pd.read_csv("../processed_data/2018_Data_Ratios_All.csv")

# convert 'Name' column into row indices
df.set_index('Name', inplace=True)

# remove ticker column
df_ticker = df['Ticker']
df = df.drop(columns=['Ticker'])

# display
display(df)
# Out:
#                                    Net cash flow / Change in cash  \
# Name
# Comcast Corporation                                      0.118923
# Kinder Morgan, Inc.                                      0.942280
# Intel Corporation                                       -0.113235
# Micron Technology, Inc.                                  0.437831
# General Electric Company                                -2.818243
# ...                                                           ...
# Willamette Valley Vineyards, Inc.                        0.013329
# Xcel Brands, Inc.                                        0.014151
# Yield10 Bioscience, Inc.                                 0.011041
# ZK International Group Co., Ltd.                         0.013465
# Zymeworks Inc.                                           0.016508
#
#                                    Average Payables  Average Receivables  \
# Name
# Comcast Corporation                        0.473944             1.638677
# Kinder Morgan, Inc.                        0.012576             0.094058
# Intel Corporation                          0.160323             0.946998
# Micron Technology, Inc.                    0.206949             0.665927
# General Electric Company                   0.982517             6.219718
# ...                                             ...                  ...
# Willamette Valley Vineyards, Inc.         -0.084326            -0.173367
# Xcel Brands, Inc.                         -0.084251            -0.171965
# Yield10 Bioscience, Inc.                  -0.084476            -0.173716
# ZK International Group Co., Ltd.          -0.083976            -0.167377
# Zymeworks Inc.                            -0.083669            -0.173406
#
#                                    Current Ratio  SG&A to Revenue  \
# Name
# Comcast Corporation                    -0.356853        -0.044034
# Kinder Morgan, Inc.                    -0.363241        -0.060170
# Intel Corporation                      -0.185465        -0.058846
# Micron Technology, Inc.                 0.007278        -0.060563
# General Electric Company               -0.187800        -0.057501
# ...                                          ...              ...
# Willamette Valley Vineyards, Inc.       0.467234        -0.049720
# Xcel Brands, Inc.                      -0.231096        -0.043934
# Yield10 Bioscience, Inc.                0.207870         0.167490
# ZK International Group Co., Ltd.       -0.201344        -0.058028
# Zymeworks Inc.                          0.742477        -0.047302
#
#                                    Days Payable Outstanding  \
# Name
# Comcast Corporation                               -0.066821
# Kinder Morgan, Inc.                               -0.066377
# Intel Corporation                                 -0.070255
# Micron Technology, Inc.                           -0.061652
# General Electric Company                          -0.064205
# ...                                                     ...
# Willamette Valley Vineyards, Inc.                 -0.067693
# Xcel Brands, Inc.                                 -0.061556
# Yield10 Bioscience, Inc.                          -0.055292
# ZK International Group Co., Ltd.                  -0.066069
# Zymeworks Inc.                                    -0.051240
#
#                                    Days Inventory Outstanding  \
# Name
# Comcast Corporation                                 -0.026435
# Kinder Morgan, Inc.                                 -0.027191
# Intel Corporation                                   -0.027910
# Micron Technology, Inc.                             -0.022345
# General Electric Company                            -0.018289
# ...                                                       ...
# Willamette Valley Vineyards, Inc.                   -0.027449
# Xcel Brands, Inc.                                   -0.013858
# Yield10 Bioscience, Inc.                            -0.015336
# ZK International Group Co., Ltd.                     0.010571
# Zymeworks Inc.                                      -0.032428
#
#                                    EBIT per Revenue  Debt to Assets  \
# Name
# Comcast Corporation                        0.050575        0.337676
# Kinder Morgan, Inc.                        0.051445        0.396621
# Intel Corporation                          0.051786       -0.141131
# Micron Technology, Inc.                    0.053225       -0.340499
# General Electric Company                   0.047457        0.114367
# ...                                             ...             ...
# Willamette Valley Vineyards, Inc.          0.050511       -0.282157
# Xcel Brands, Inc.                          0.049769       -0.270288
# Yield10 Bioscience, Inc.                  -0.104876        0.447922
# ZK International Group Co., Ltd.           0.050375       -0.048186
# Zymeworks Inc.                             0.042726       -0.555560
#
#                                    Debt to Equity  Payout Ratio  \
# Name
# Comcast Corporation                      0.055796      0.010642
# Kinder Morgan, Inc.                      0.022762      0.152212
# Intel Corporation                       -0.032390     -0.007532
# Micron Technology, Inc.                 -0.047726     -0.057847
# General Electric Company                 0.186120     -0.084821
# ...                                           ...           ...
# Willamette Valley Vineyards, Inc.       -0.045388     -0.057847
# Xcel Brands, Inc.                       -0.043898     -0.057847
# Yield10 Bioscience, Inc.                 0.024684     -0.057847
# ZK International Group Co., Ltd.        -0.020209     -0.057847
# Zymeworks Inc.                          -0.058219     -0.057847
#
#                                    Return on Equity  R&D to Revenue  \
# Name
# Comcast Corporation                       -0.015926       -0.049350
# Kinder Morgan, Inc.                       -0.015927       -0.049350
# Intel Corporation                         -0.015925       -0.046837
# Micron Technology, Inc.                   -0.015925       -0.048425
# General Electric Company                  -0.015931       -0.049350
# ...                                             ...             ...
# Willamette Valley Vineyards, Inc.         -0.015927       -0.049350
# Xcel Brands, Inc.                         -0.015927       -0.049350
# Yield10 Bioscience, Inc.                  -0.015936        0.063150
# ZK International Group Co., Ltd.          -0.015926       -0.048954
# Zymeworks Inc.                            -0.015928       -0.035298
#
#                                    Price-to-Earnings Ratio  Dividend Yield
# Name
# Comcast Corporation                              -0.108544        0.033407
# Kinder Morgan, Inc.                              -0.016143        0.213109
# Intel Corporation                                -0.136551        0.021842
# Micron Technology, Inc.                          -0.191694       -0.205898
# General Electric Company                         -0.231417        0.246024
# ...                                                    ...             ...
# Willamette Valley Vineyards, Inc.                -0.059390       -0.205898
# Xcel Brands, Inc.                                -0.057434       -0.205898
# Yield10 Bioscience, Inc.                         -0.231417       -0.205898
# ZK International Group Co., Ltd.                 -0.174568       -0.205898
# Zymeworks Inc.                                   -0.231417       -0.205898
#
# [3568 rows x 15 columns]

# %%
random_state = 0
af = AffinityPropagation(preference=-100).fit(df)
cluster_centers_indices = af.cluster_centers_indices_
labels = af.labels_
labels_pred = af.predict(df)
# Out:
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_affinity_propagation.py:146: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 0.25 which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(("'random_state' has been introduced in 0.23. "

# %%
n_clusters_ = len(cluster_centers_indices)
print('Estimated number of clusters: %d' % n_clusters_)
# Out:
# Estimated number of clusters: 46

# %%
'''first couple labels aren't really relevant'''
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_pred, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_pred, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_pred, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_pred, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_pred, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(df, labels, metric='sqeuclidean'))
# Out:
# Homogeneity: 1.000
# Completeness: 1.000
# V-measure: 1.000
# Adjusted Rand Index: 1.000
# Adjusted Mutual Information: 1.000
# Silhouette Coefficient: 0.367

# %%
from itertools import cycle

# %%
frame = pd.DataFrame(df)
frame['cluster'] = labels
frame['cluster'].value_counts()
# Out:
# 35    1498
# 22     931
# 41     441
# 18     206
# 11     100
# 14      97
# 7       93
# 10      52
# 4       21
# 39      16
# 28      11
# 20      11
# 29      10
# 12       8
# 21       7
# 15       7
# 6        6
# 38       6
# 31       5
# 26       4
# 24       4
# 0        4
# 8        4
# 1        2
# 16       2
# 2        2
# 32       1
# 30       1
# 45       1
# 34       1
# 17       1
# 37       1
# 33       1
# 27       1
# 25       1
# 23       1
# 19       1
# 13       1
# 36       1
# 9        1
# 5        1
# 3        1
# 43       1
# 42       1
# 40       1
# 44       1
# Name: cluster, dtype: int64

# %%
print(af.cluster_centers_)
# Out:
# [[-1.31554380e+01 -8.44828783e-02 -1.73741205e-01 -4.50212862e-01
#   -4.98751655e-02 -7.54170646e-02 -3.40943703e-02  5.18232988e-02
#   -2.00277566e-01  6.65005866e-02  1.50425924e-02 -1.59263271e-02
#   -4.93499165e-02 -1.32649368e-01  1.10803303e-01]
#  [ 2.06290889e-01 -8.44828783e-02  1.75875926e+00 -3.88318038e-01
#   -5.34638533e-02 -7.54170646e-02 -1.89483118e-02  4.90233074e-02
#   -4.14332208e-01 -1.34430082e-02 -2.45455527e+01 -1.59269694e-02
#   -4.93499165e-02 -2.31416720e-01  8.32253722e-02]
#  [ 2.11418314e+00  1.33692761e+01  9.77874073e+00 -1.80502432e-01
#   -4.62313057e-02  3.52755648e-01  5.25302296e-02  5.13142081e-02
#   -8.62089735e-02  1.23098986e-01 -1.40365586e-02 -1.59263563e-02
#   -4.93499165e-02 -1.55265885e-01  4.05240596e-02]
#  [-4.70686858e+01  1.39139976e+01  1.26370852e+01 -3.98532689e-01
#   -4.79717315e-02  9.71335112e-02  9.66989689e-03  5.20684899e-02
#   -1.46160368e-01  9.37841424e-02 -5.42759939e-03 -1.59262962e-02
#   -4.93499165e-02 -1.31658129e-01  2.00630141e-02]
#  [-2.71017548e-02  2.60083765e+00  4.39848272e+00 -3.48092171e-01
#  [ 1.47795312e-02 -8.44114473e-02 -1.72788452e-01  5.19069840e-01
#   -5.17986620e-02 -7.01724680e-02 -1.11603135e-02  5.04695348e-02
#   -4.13929849e-01 -5.21543842e-02 -5.78465952e-02 -1.59258192e-02
#   -4.74743459e-02 -1.16791386e-01 -2.05898098e-01]
#  [ 1.18504279e-02 -7.18359410e-02  6.95601661e-01 -3.16199245e-01
#   -4.68231508e-02  3.37164372e-01  1.02281394e+01  4.97144332e-02
#    1.35705043e+00  1.57001753e+01 -1.29396611e-01 -1.59273554e-02
#   -4.93499165e-02 -2.31416720e-01  6.38342435e-01]
#  [ 1.47672185e-02 -8.42343745e-02 -1.71354918e-01 -4.78047833e-01
#   -4.19404287e-02  2.29138158e+01  6.13396567e+01  4.96208250e-02
#   -2.10269208e-02  1.37851396e-01 -4.88294553e-01 -1.59269705e-02
#   -4.93499165e-02 -2.31416720e-01  4.75543681e-01]
#  [ 1.46098461e-02 -8.43114495e-02 -1.73741205e-01 -4.96300033e-01
#    3.77133545e-01  8.75812801e-01 -3.40943703e-02 -1.85100572e-01
#    4.84420304e+01 -1.09600371e-01 -5.78465952e-02 -1.59223163e-02
#    3.75335593e-02 -2.31416720e-01 -2.05898098e-01]
#  [ 1.48439346e-02 -8.44167896e-02 -1.73740582e-01  8.00153717e-01
#    1.62480139e+01  1.50213587e+01 -3.40943703e-02 -1.47296817e+01
#   -5.55559989e-01 -5.82190203e-02 -5.78465952e-02 -1.59357788e-02
#    1.00040175e+01 -2.31416720e-01 -2.05898098e-01]]

# %%
print(af.labels_) # respective cluster for each company (company at index 1 is in cluster 1)
# Out:
# [ 7 22  7 ... 22 35 41]

# %%
counts = df['cluster'].value_counts()
features_dupl = df;
for index, feature in features_dupl.iterrows():
    if counts[feature['cluster']] < 10:
        df = df.drop([index])
        df_ticker = df_ticker.drop([index])

# %%
#reorder clusters (first cluster is 0, second is 1, etc)
mappings = np.array([])
new_index = 0
features_dupl = df;
for index, feature in features_dupl.iterrows():
    if len(np.where(mappings == feature['cluster'])[0]) == 0:
        mappings = np.append(mappings, int(feature['cluster']))
        df.loc[index, 'cluster'] = new_index
        new_index = new_index + 1
    else:
        df.loc[index, 'cluster'] = np.where(mappings == feature['cluster'])[0][0]

# %%
df['cluster'].value_counts()
# Out:
# 2     1498
# 1      931
# 5      441
# 6      206
# 4      100
# 8       97
# 0       93
# 7       52
# 3       21
# 10      16
# 11      11
# 9       11
# 12      10
# Name: cluster, dtype: int64

# %%
df.to_csv("../processed_data/2018_Clusters_Ratios_AF_All.csv");

# %%
df_clusters_only = df[['cluster']]
df_clusters_only = df_clusters_only.reset_index()
df_clusters_only['ticker'] = df_ticker.to_numpy()
df_clusters_only = df_clusters_only.rename(columns={"Name": "name"})
df_clusters_only.to_json (r'../processed_data/2018_Clusters_Ratios_AF_All.json', orient='records')
