# %%
# import libraries
import pandas as pd;

# %%
# read CSVs
financials_2018 = pd.read_csv('../data/2018_Financial_Data.csv');

# %%
# print all industries available
financials_2018.Sector.unique()
# Out:
# array(['Consumer Cyclical', 'Energy', 'Technology', 'Industrials',
#        'Financial Services', 'Basic Materials', 'Communication Services',
#        'Consumer Defensive', 'Healthcare', 'Real Estate', 'Utilities'],
#       dtype=object)

# %%
# clean up data
# we only want companies from the consumer packaged goods industry, "Consumer Cyclical".
# we can consider "Consumer Defensive" as well?
consumer_2018 = financials_2018.loc[financials_2018['Sector'] == "Consumer Cyclical"];

# %%
# add name for ticker column
consumer_2018.rename(columns={consumer_2018.columns[0]: "Ticker"}, inplace=True)
# Out:
# c:\users\trieu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
pd.set_option('display.max_columns', 110)
pd.set_option('display.max_rows', 110)

# %%
# Remove specific keywords.
# Not used anymore, was used to isolate attributes.

#financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-5:] != 'ratio']
#financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'ratios']
financials_2018_cols = [c for c in financials_2018.columns if c.lower()[-6:] != 'margin']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'turnover']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-6:] != 'growth']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-18:] != 'growth (per share)']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-9:] != 'per share']
financials_2018_cols = [c for c in financials_2018_cols if c.lower()[-8:] != 'pershare']

# %%
# Select specific attributes from the consumer dataset
consumer_2018_accounts = consumer_2018[['Ticker',
                               'Revenue',
                               'Cost of Revenue',
                               'Gross Profit',
                               'R&D Expenses',
                               'SG&A Expense',
                               'Operating Expenses',
                               'Operating Income',
                               'Interest Expense',
                               'Earnings before Tax',
                               'Income Tax Expense',
                               'Net Income',
                               'Preferred Dividends',
                               'Net Income Com',
                               'EBITDA',
                               'EBIT',
                               'Consolidated Income',
                               'Cash and cash equivalents',
                               'Short-term investments',
                               'Cash and short-term investments',
                               'Receivables',
                               'Inventories',
                               'Total current assets',
                               'Property, Plant & Equipment Net',
                               'Goodwill and Intangible Assets',
                               'Long-term investments',
                               'Tax assets',
                               'Total non-current assets',
                               'Total assets',
                               'Payables',
                               'Short-term debt',
                               'Total current liabilities',
                               'Long-term debt',
                               'Total debt',
                               'Deferred revenue',
                               'Tax Liabilities',
                               'Deposit Liabilities',
                               'Total non-current liabilities',
                               'Total liabilities',
                               'Other comprehensive income',
                               'Retained earnings (deficit)',
                               'Total shareholders equity',
                               'Investments',
                               'Net Debt',
                               'Other Assets',
                               'Other Liabilities',
                               'Depreciation & Amortization',
                               'Stock-based compensation',
                               'Operating Cash Flow',
                               'Capital Expenditure',
                               'Acquisitions and disposals',
                               'Investment purchases and sales',
                               'Investing Cash flow',
                               'Issuance (repayment) of debt',
                               'Issuance (buybacks) of shares',
                               'Dividend payments',
                               'Financing Cash Flow',
                               'Free Cash Flow',
                               'Market Cap',
                               'Enterprise Value',
                               'Working Capital',
                               '2019 PRICE VAR [%]',
                               'Class']]
consumer_2018_ratios = consumer_2018[['Net cash flow / Change in cash',
                                      'Net Cash/Marketcap',
                                      'priceBookValueRatio',
                                      'priceToBookRatio',
                                      'priceToSalesRatio',
                                      'priceEarningsRatio',
                                      'priceToFreeCashFlowsRatio',
                                      'priceToOperatingCashFlowsRatio',
                                      'priceCashFlowRatio',
                                      'priceEarningsToGrowthRatio',
                                      'priceSalesRatio',
                                      'dividendYield',
                                      'enterpriseValueMultiple',
                                      'ebitperRevenue',
                                      'niperEBT',
                                      'returnOnAssets',
                                      'returnOnEquity',
                                      'eBTperEBIT',
                                      'eBITperRevenue',
                                      'currentRatio',
                                      'quickRatio',
                                      'cashRatio',
                                      'daysOfSalesOutstanding',
                                      'daysOfInventoryOutstanding',
                                      'daysOfPayablesOutstanding',
                                      'companyEquityMultiplier',
                                      'payoutRatio',
                                      'operatingCashFlowSalesRatio',
                                      'freeCashFlowOperatingCashFlowRatio',
                                      'PE ratio',
                                      'Price to Sales Ratio',
                                      'EV to Sales',
                                      'Enterprise Value over EBITDA',
                                      'Earnings Yield',
                                      'shortTermCoverageRatios',
                                      'dividendPayoutRatio',
                                      'Free Cash Flow Yield',
                                      'Debt to Equity',
                                      'Debt to Assets',
                                      'Net Debt to EBITDA',
                                      'Current ratio',
                                      'Dividend Yield',
                                      'Payout Ratio',
                                      'SG&A to Revenue',
                                      'R&D to Revenue',
                                      'Intangibles to Total Assets',
                                      'Capex to Operating Cash Flow',
                                      'Capex to Revenue',
                                      'ROIC',
                                      'Working Capital',
                                      'Average Receivables',
                                      'Average Payables',
                                      'Days Sales Outstanding',
                                      'Days Payables Outstanding',
                                      'Days of Inventory on Hand',
                                      'ROE']]

# %%
# Shows the rows that contain at least one nan
consumer_2018_accounts_nan_rows = consumer_2018_accounts[consumer_2018_accounts.isna().any(axis=1)]
consumer_2018_ratios_nan_rows = consumer_2018_ratios[consumer_2018_ratios.isna().any(axis=1)]

# %%
consumer_2018_ratios_nan_rows
# Out:
#       Net cash flow / Change in cash  Net Cash/Marketcap  priceBookValueRatio  \
# 8                      -1.400400e+07             -0.2695               0.0000
# 49                      8.912356e+09              0.0190                  NaN
# 64                      2.481000e+09              0.0827               2.2689
# 71                     -4.847400e+08             -0.6559               5.2585
# 73                      1.270830e+08             -0.4978               0.0000
# ...                              ...                 ...                  ...
# 4320                    2.560000e+06              0.0514               1.0809
# 4331                   -2.461650e+07              1.6241               0.7302
# 4354                   -2.192100e+07                 NaN                  NaN
# 4362                   -1.559100e+07             -0.4945               0.7670
# 4375                    1.412800e+06             -0.0124               0.0000
#
#       priceToBookRatio  priceToSalesRatio  priceEarningsRatio  \
# 8               0.0000             4.3949             21.9615
# 49                 NaN            14.3604             44.7990
# 64              4.9254             2.1476             10.7955
# 71              0.0000             0.7637              0.0000
# 73              0.0000             0.8620             12.0853
# ...                ...                ...                 ...
# 4320            1.0809             0.1897              0.0000
# 4331            0.7318             0.8999              0.0000
# 4354               NaN                NaN                 NaN
# 4362            0.0000             0.3213              0.9792
# 4375            0.0000             8.5544             20.4633
#
#       priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# 8                       16.7094                         13.4873
# 49                      34.1647                         20.7673
# 64                      19.7014                         16.9904
# 71                       0.0000                       -126.2238
# 73                      11.8732                          8.8269
# ...                         ...                             ...
# 4320                     0.0000                          8.8217
# 4331                     0.0000                         -0.3319
# 4354                        NaN                             NaN
# 4362                     0.0000                         -2.1694
# 4375                    55.3104                         17.7546
#
#       priceCashFlowRatio  priceEarningsToGrowthRatio  priceSalesRatio  \
# 8              13.492365                   21.576187         4.396576
# 49             28.834360                   56.597548        14.494604
# 64              0.000000                    0.000000         0.000000
# 71                   NaN                         NaN         0.763414
# 73              8.974553                   12.033776         0.876390
# ...                  ...                         ...              ...
# 4320            8.456321                         NaN         0.181875
# 4331                 NaN                         NaN         0.899287
# 4354                 NaN                         NaN              NaN
# 4362                 NaN                    0.978683         0.210388
# 4375           17.592286                   20.402042         8.476243
#
#       dividendYield  enterpriseValueMultiple  ebitperRevenue  niperEBT  \
# 8          0.007939                15.598533        0.306834  0.827759
# 49        -0.000000                41.695359        0.343067  0.778848
# 64              NaN                 1.067008        0.213927  1.027243
# 71        -0.000000               187.739994       -0.052099       NaN
# 73         0.000087                 9.167381        0.137050  0.644662
# ...             ...                      ...             ...       ...
# 4320      -0.000000                      NaN       -0.032511       NaN
# 4331      -0.000000                      NaN       -0.887313       NaN
# 4354            NaN                      NaN        0.000000  0.000000
# 4362      -0.000000                 1.403716        0.233196  1.009858
# 4375       0.003530                15.276490        0.575964  0.766882
#
#       returnOnAssets  returnOnEquity  eBTperEBIT  eBITperRevenue  \
# 8            -1.4481         -0.6472    0.802291        0.306834
# 49            0.0771          0.1752    0.958466        0.343067
# 64            0.4383          0.2280    0.980203        0.213927
# 71           -0.3057         -0.8120         NaN       -0.052099
# 73            0.3428         -0.2587    0.824298        0.137050
# ...              ...             ...         ...             ...
# 4320         -0.1128         -0.2363         NaN       -0.032511
# 4331         -0.7874         -0.7290         NaN       -0.887313
# 4354             NaN             NaN         NaN        0.000000
# 4362          0.8617          0.7837    0.912845        0.233196
# 4375          2.3844         -6.2651    0.940602        0.575964
#
#       currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  \
# 8         0.171000    0.102390   0.019265                 -3.4783
# 49        0.299200    1.547824   1.467558                  0.0000
# 64        3.172000    2.463331   1.421262                -66.2106
# 71        1.863000    1.241688   0.471799                -72.9548
# 73        1.751000    0.471951   0.444593               -126.8105
# ...            ...         ...        ...                     ...
# 4320      1.566000    0.710195   0.369294                -84.3708
# 4331      1.585000    1.517186   0.888247                  0.0000
# 4354      1.558559    1.135135   0.144144                  0.0000
# 4362      1.806000    0.578436   0.118910               -118.4151
# 4375      1.943000    1.816555   0.206356                 -8.4091
#
#       daysOfInventoryOutstanding  daysOfPayablesOutstanding  \
# 8                        14.7374                    46.5525
# 49                        0.0000                     0.0000
# 64                       65.8963                    63.2360
# 71                       78.4264                    43.4918
# 73                        1.7840                    32.8790
# ...                          ...                        ...
# 4320                     40.9981                    55.7112
# 4331                    278.2603                   274.3395
# 4354                     91.4374                     5.8187
# 4362                     27.7986                    30.2035
# 4375                      7.8179                     6.8046
#
#       companyEquityMultiplier  payoutRatio  operatingCashFlowSalesRatio  \
# 8                         NaN        0.173                     0.325857
# 49                   1.960309        0.000                     0.502685
# 64                   1.367626        0.000                     0.129715
# 71                   7.975337        0.000                    -0.006051
# 73                        NaN        0.000                     0.097653
# ...                       ...          ...                          ...
# 4320                 4.150465        0.000                     0.021508
# 4331                 2.346755        0.000                    -2.711574
# 4354                 6.910615          NaN                     0.114391
# 4362                 3.136781        0.000                    -0.148110
# 4375                      NaN        0.072                     0.481816
#
#       freeCashFlowOperatingCashFlowRatio  PE ratio  Price to Sales Ratio  \
# 8                               0.810838   21.9615                4.3949
# 49                              0.843981   44.7990               14.3604
# 64                              0.836750   10.7955                2.1476
# 71                                   NaN    0.0000                0.7637
# 73                              0.755868   12.0853                0.8620
# ...                                  ...       ...                   ...
# 4320                           -0.084038    0.0000                0.1897
# 4331                                 NaN    0.0000                0.8999
# 4354                            0.000000       NaN                   NaN
# 4362                                 NaN    0.9792                0.3213
# 4375                            0.318822   20.4633                8.5544
#
#       EV to Sales  Enterprise Value over EBITDA  Earnings Yield  \
# 8          5.5792                       15.5433          0.0455
# 49            NaN                           NaN          0.0223
# 64         1.9699                        9.3765          0.0926
# 71         1.2646                      155.5079         -0.1552
# 73         1.2911                        8.1083          0.0827
# ...           ...                           ...             ...
# 4320       0.1800                        0.0000         -0.2179
# 4331      -0.5616                        0.7182         -0.9985
# 4354          NaN                           NaN             NaN
# 4362       0.4802                        1.7769          1.0212
# 4375       8.6609                       14.9249          0.0489
#
#       shortTermCoverageRatios  dividendPayoutRatio  Free Cash Flow Yield  \
# 8                  626.806000             0.171303                0.0601
# 49                  20.870106            -0.000000                0.0368
# 64                        NaN             0.018747                0.0508
# 71                  -6.541427                  NaN               -0.0521
# 73                  21.028514             0.001045                0.0856
# ...                       ...                  ...                   ...
# 4320                 3.190556                  NaN               -0.0095
# 4331                -9.216229                  NaN               -3.0891
# 4354                      NaN                  NaN                   NaN
# 4362                -5.046500            -0.000000               -0.4995
# 4375                10.796020             0.072029                0.0180
#
#       Debt to Equity  Debt to Assets  Net Debt to EBITDA  Current ratio  \
# 8            -3.7909          0.8428              3.2993         0.1710
# 49            0.3432          0.1751             -0.8951         0.2992
# 64            0.0000          0.0000             -1.0670         3.1720
# 71            4.3482          0.5452             61.5938         1.8630
# 73           -1.8063          1.1854              2.6948         1.7510
# ...              ...             ...                 ...            ...
# 4320          0.6637          0.1599              4.0472         1.5660
# 4331          0.2387          0.1017              1.8691         1.5850
# 4354             NaN             NaN                 NaN            NaN
# 4362          0.6511          0.2076              0.5879         1.8060
# 4375         -5.9979          0.6181              0.1834         1.9430
#
#       Dividend Yield  Payout Ratio  SG&A to Revenue  R&D to Revenue  \
# 8             0.0079         0.173           0.2272          0.0214
# 49            0.0000         0.000           0.1740          0.0909
# 64            0.0000         0.000           0.1191          0.0000
# 71            0.0000         0.000           0.4503          0.0000
# 73            0.0000         0.000           0.2593          0.0000
# ...              ...           ...              ...             ...
# 4320          0.0000         0.000           0.1191          0.0000
# 4331          0.0000         0.000           1.4387          0.0000
# 4354             NaN           NaN           0.3643             NaN
# 4362          0.0000         0.000           0.5140          0.0000
# 4375          0.0035         0.072           0.3591          0.0000
#
#       Intangibles to Total Assets  Capex to Operating Cash Flow  \
# 8                          0.5862                        0.1892
# 49                         0.2644                        0.1560
# 64                         0.4278                        0.1632
# 71                         0.2647                        0.0000
# 73                         0.0612                        0.2441
# ...                           ...                           ...
# 4320                       0.0000                        1.0840
# 4331                       0.0009                        0.0000
# 4354                          NaN                        0.0882
# 4362                       0.5054                        0.0000
# 4375                       0.0130                        0.6812
#
#       Capex to Revenue    ROIC  Working Capital  Average Receivables  \
# 8               0.0616  0.2029    -2.325000e+09         2.373635e+08
# 49              0.0784  0.1427     1.210450e+11         0.000000e+00
# 64              0.0212  0.1588     3.821000e+09         1.763000e+09
# 71              0.0338 -0.0432     1.087170e+09         1.047368e+09
# 73              0.0238  0.4883     7.190370e+08         2.471100e+07
# ...                ...     ...              ...                  ...
# 4320            0.0233 -0.1195     1.641300e+07         9.599000e+06
# 4331            0.0683  0.0000     8.247453e+06         4.384122e+06
# 4354            0.0101     NaN              NaN         1.110000e+08
# 4362            0.0124 -0.0596     3.639700e+07         1.554800e+07
# 4375            0.3282  1.6036     1.176800e+07         1.674550e+06
#
#       Average Payables  Days Sales Outstanding  Days Payables Outstanding  \
# 8         7.651705e+08                 14.7374                    46.5525
# 49        0.000000e+00                  0.0000                     0.0000
# 64        1.900500e+09                 65.8963                    63.2360
# 71        5.550655e+08                 78.4264                    43.4918
# 73        5.001350e+08                  1.7840                    32.8790
# ...                ...                     ...                        ...
# 4320      1.194600e+07                 40.9981                    55.7112
# 4331      3.434555e+06                278.2603                   274.3395
# 4354      7.500000e+06                 91.4374                     5.8187
# 4362      2.978900e+07                 27.7986                    30.2035
# 4375      1.712400e+06                  7.8179                     6.8046
#
#       Days of Inventory on Hand     ROE
# 8                       -3.4783 -0.6472
# 49                       0.0000  0.1752
# 64                     -66.2106  0.2280
# 71                     -72.9548 -0.8120
# 73                    -126.8105 -0.2587
# ...                         ...     ...
# 4320                   -84.3708 -0.2363
# 4331                     0.0000 -0.7290
# 4354                     0.0000     NaN
# 4362                  -118.4151  0.7837
# 4375                    -8.4091 -6.2651
#
# [307 rows x 56 columns]

# %%
# Shows the number of nans in each column (accounts dataset)
consumer_2018_accounts.isnull().sum().sort_values()
# Out:
# Ticker                              0
# Financing Cash Flow                 0
# Investing Cash flow                 0
# Capital Expenditure                 0
# Operating Cash Flow                 0
# Total shareholders equity           0
# Total liabilities                   0
# Long-term debt                      0
# 2019 PRICE VAR [%]                  0
# Payables                            0
# Total assets                        0
# Total current assets                0
# Receivables                         0
# Cash and cash equivalents           0
# Total current liabilities           0
# Class                               0
# Gross Profit                        0
# Operating Income                    0
# Revenue                             2
# Net Income Com                      2
# Depreciation & Amortization         2
# SG&A Expense                        2
# Property, Plant & Equipment Net     2
# Income Tax Expense                  2
# Cost of Revenue                     4
# Retained earnings (deficit)         4
# Long-term investments               4
# Earnings before Tax                 4
# Total debt                          6
# EBIT                                6
# Operating Expenses                  6
# Goodwill and Intangible Assets      6
# Interest Expense                    7
# Free Cash Flow                      7
# Deferred revenue                    7
# Tax Liabilities                     7
# Investment purchases and sales      7
# Other comprehensive income          7
# Cash and short-term investments     7
# Stock-based compensation            7
# Other Liabilities                   7
# Other Assets                        7
# Consolidated Income                 8
# Issuance (repayment) of debt        8
# Short-term debt                     8
# Investments                         8
# Net Income                          8
# EBITDA                              8
# Inventories                        10
# Issuance (buybacks) of shares      10
# Tax assets                         11
# Short-term investments             12
# Net Debt                           14
# Acquisitions and disposals         15
# Deposit Liabilities                17
# Dividend payments                  17
# Preferred Dividends                18
# R&D Expenses                       19
# Total non-current assets           32
# Total non-current liabilities      33
# Market Cap                         34
# Working Capital                    45
# Enterprise Value                   65
# dtype: int64

# %%
# Shows the number of nans in each column (ratios dataset)
consumer_2018_ratios.isnull().sum().sort_values()
# Out:
# Net cash flow / Change in cash          1
# Average Payables                       11
# Average Receivables                    11
# Capex to Operating Cash Flow           11
# currentRatio                           12
# Days Payables Outstanding              13
# Days Sales Outstanding                 13
# Capex to Revenue                       13
# SG&A to Revenue                        13
# daysOfPayablesOutstanding              13
# daysOfInventoryOutstanding             13
# cashRatio                              13
# quickRatio                             13
# eBITperRevenue                         13
# operatingCashFlowSalesRatio            13
# ebitperRevenue                         13
# daysOfSalesOutstanding                 15
# Days of Inventory on Hand              15
# Intangibles to Total Assets            17
# Debt to Assets                         18
# Debt to Equity                         18
# Payout Ratio                           18
# payoutRatio                            18
# ROE                                    19
# Earnings Yield                         19
# R&D to Revenue                         19
# Price to Sales Ratio                   19
# PE ratio                               19
# priceToFreeCashFlowsRatio              19
# priceEarningsRatio                     19
# priceSalesRatio                        19
# priceToSalesRatio                      19
# returnOnEquity                         19
# Dividend Yield                         19
# dividendYield                          20
# Net Debt to EBITDA                     29
# priceToOperatingCashFlowsRatio         36
# Free Cash Flow Yield                   36
# Net Cash/Marketcap                     39
# ROIC                                   45
# Working Capital                        45
# Current ratio                          45
# returnOnAssets                         46
# companyEquityMultiplier                64
# priceToBookRatio                       64
# priceBookValueRatio                    64
# Enterprise Value over EBITDA           65
# EV to Sales                            65
# enterpriseValueMultiple                73
# freeCashFlowOperatingCashFlowRatio     79
# priceCashFlowRatio                     87
# eBTperEBIT                             98
# niperEBT                              120
# priceEarningsToGrowthRatio            126
# dividendPayoutRatio                   126
# shortTermCoverageRatios               158
# dtype: int64

# %%
# Drops the nan rows from the dataset
consumer_2018_accounts = consumer_2018_accounts.dropna()

# %% [markdown]
# ### Consumer 2018 Dataset with only accounts

# %%
consumer_2018_accounts
# Out:
#      Ticker       Revenue  Cost of Revenue  Gross Profit  R&D Expenses  ...  \
# 0     CMCSA  9.450700e+10     0.000000e+00  9.450700e+10           0.0  ...
# 8      SIRI  5.770692e+09     2.308606e+09  3.462086e+09   123219000.0  ...
# 11      CZR  8.391000e+09     4.181000e+09  4.210000e+09           0.0  ...
# 12        F  1.603380e+11     1.457320e+11  1.460600e+10           0.0  ...
# 25      NKE  3.639700e+10     2.044100e+10  1.595600e+10           0.0  ...
# ...     ...           ...              ...           ...           ...  ...
# 4353   UONE  4.390980e+08     1.253640e+08  3.137340e+08           0.0  ...
# 4354  UONEK  4.390980e+08     8.114600e+07  2.805450e+08           NaN  ...
# 4362   VNCE  2.725820e+08     1.507930e+08  1.217890e+08           0.0  ...
# 4375   WINA  7.251110e+07     4.670400e+06  6.784070e+07           0.0  ...
# 4385   XELB  3.546600e+07     2.702000e+06  3.276400e+07           0.0  ...
#
#         Market Cap  Enterprise Value  Working Capital  2019 PRICE VAR [%]  \
# 0     1.549106e+11      2.628396e+11    -5.755000e+09           32.794573
# 8     2.536181e+10      3.219581e+10    -2.325000e+09           22.161943
# 11    4.547487e+09      2.193249e+10     2.650000e+08           96.531795
# 12    3.043096e+10      1.506930e+11     1.908000e+10           25.537204
# 25    1.157243e+11      1.142893e+11     9.094000e+09           38.243248
# ...            ...               ...              ...                 ...
# 4353  9.823137e+07      9.948044e+08     6.192100e+07           -3.809520
# 4354           NaN               NaN              NaN            4.395600
# 4362  8.758343e+07      1.308934e+08     3.639700e+07           69.539661
# 4375  6.202911e+08      6.280086e+08     1.176800e+07           26.169646
# 4385  2.066153e+07      3.139953e+07     7.759000e+06           27.118650
#
#       Class
# 0         1
# 8         1
# 11        1
# 12        1
# 25        1
# ...     ...
# 4353      0
# 4354      1
# 4362      1
# 4375      1
# 4385      1
#
# [506 rows x 63 columns]
